# %% [markdown]
# 로그 저장 기능이 전부 삭제된 오리지널 챗봇 파일입니다. \
# Handoff 판단 노드가 추가되었습니다. \
# [버전1] 사역자 대화 모범 데이터셋만 사용합니다. \
# Upstage API를 사용합니다.

# %%
import os
import logging
import json
import pymongo
import uuid
from pymongo import MongoClient
from datetime import datetime
from dotenv import load_dotenv
import pandas as pd
from typing import Literal, TypedDict, List
from pydantic import BaseModel, Field
#from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_upstage import ChatUpstage, UpstageEmbeddings
from langchain.schema import Document
from langchain_community.retrievers import BM25Retriever
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableConfig, RunnableLambda
from langchain.retrievers import EnsembleRetriever
from langgraph.graph import StateGraph, START, END
from langchain.retrievers.document_compressors import LLMChainExtractor
from langchain.retrievers import ContextualCompressionRetriever
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# 환경 변수 로드
load_dotenv()
#print(os.getenv("UPSTAGE_API_KEY"))

# 로거 설정
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
console_handler = logging.StreamHandler()
logger.addHandler(console_handler)

# %%
#----1. 모델 정의----
#model = ChatOpenAI(model_name='gpt-4o', temperature=0)
model = ChatUpstage(
    model="solar-pro",
    temperature=0
)

# %%
#----2. State 정의----
class State(TypedDict):
    session_id: str
    conversation_count: int
    default_count: int
    input_msg: str
    initial_translated: str #Eng #rewrite 하면 여기로 저장됨
    route: str
    source: str
    documents: List[str]
    generation: str
    final_translated: str #Persian

# %%
#----3. RAG 설정 (미리 로드)----

base_dir = os.getcwd() 
print(f"Current Working Directory: {base_dir}")

data_folder = os.path.join(base_dir, 'data')
persist_directory = os.path.join(base_dir, 'chroma_db')

print(f"Data Folder Path: {data_folder}")
print(f"Chroma DB Path: {persist_directory}")

docs = []

print(f"'{data_folder}'에서 데이터 로드 시작...")

# os.walk를 사용하여 'data' 폴더와 모든 하위 폴더(gq, book, whatsapp) 탐색
for dirpath, _, filenames in os.walk(data_folder):
    for file_name in filenames:
        
        if file_name.startswith('.'): #.DS_store 무시하기
            continue
        
        file_path = os.path.join(dirpath, file_name)
        file_name_lower = file_name.lower()
        
        # 1. 엑셀 파일 처리
        if file_name_lower.endswith(('.xlsx', '.xls')):
            try:
                df = pd.read_excel(file_path)
                print(f"  [Excel] 로드: {file_path}")

                title_column = None
                if 'big_title_eng' in df.columns:
                    title_column = 'big_title_eng'
                elif 'big_title_ara' in df.columns:
                    title_column = 'big_title_ara'

                for index, row in df.iterrows():
                    content = f"질문: {row.get('Question_ENG', '')}\n\n답변: {row.get('Answer_ENG', '')}"
                    metadata = {
                        # URL_ENG가 없으면 파일 경로를 source로 사용
                        "source": row.get('URL_ENG', file_path), 
                        "row_number": index + 1
                    }
                    
                    # 카테고리 설정: 1순위 엑셀 컬럼, 2순위 하위 폴더명
                    if title_column and pd.notna(row.get(title_column)):
                        metadata["category"] = row.get(title_column)
                    else:
                        metadata["category"] = os.path.basename(dirpath) # 예: 'gq'

                    docs.append(Document(page_content=content, metadata=metadata))
            except Exception as e:
                print(f"  [Error] 엑셀 파일 처리 중 오류 {file_path}: {e}")

        # 2. 텍스트 파일 처리 
        elif file_name_lower.endswith('.txt'):
            try:
                # 텍스트 파일 인코딩은 'utf-8'로 가정 (환경에 따라 다를 수 있음)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                print(f"  [Text] 로드: {file_path}")
                
                metadata = {
                    "source": file_path,
                    "category": os.path.basename(dirpath) # 예: 'book'
                }
                docs.append(Document(page_content=content, metadata=metadata))
            except Exception as e:
                print(f"  [Error] 텍스트 파일 처리 중 오류 {file_path}: {e}")
        
        # 3. CSV 파일 처리
        elif file_name_lower.endswith('.csv'):
            try:
                df = pd.read_csv(file_path)
                print(f"  [Csv] 로드: {file_path}")
                
                # Q&A 컬럼 확인 및 데이터 처리
                if 'Question' in df.columns and 'Answer' in df.columns:
                    for index, row in df.iterrows():
                        content = f"질문: {row.get('Question', '')}\n\n답변: {row.get('Answer', '')}"
                        metadata = {
                            "source": file_path,
                            "row_number": index + 1,
                        }
                        docs.append(Document(page_content=content, metadata=metadata))
                    print(f"  -> {len(df)}개의 Q&A 데이터 추가 완료")
                else:
                    print(f"  [Warning] {file_path}에 'Question' 또는 'Answer' 컬럼이 없습니다.")
                    
            except Exception as e:
                print(f"  [Error] 추가 CSV 파일 처리 중 오류: {e}")
        else:
            print(f"  [Info] {file_path} 파일이 없어 건너뜁니다.")

print(f"총 {len(docs)}개의 문서를 로드했습니다.")


# embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
embeddings = UpstageEmbeddings(
    model="solar-embedding-1-large"
)

# Chroma DB 존재 여부 확인 및 처리 
if os.path.exists(persist_directory) and len(os.listdir(persist_directory)) > 0:
    print("기존 Chroma DB 로드")
    # 기존 DB를 로드할 때도 embedding_function을 꼭 넣어줘야 검색이 가능
    chroma_db = Chroma(
        persist_directory=persist_directory,
        embedding_function=embeddings 
    )
else:
    print("새로운 Chroma DB 생성 및 저장")
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    split_docs = text_splitter.split_documents(docs)
    print(f"청크 후 문서 개수: {len(split_docs)}")

    # from_documents를 사용하면 persist_directory가 지정된 경우 자동 저장
    chroma_db = Chroma.from_documents(
        documents=split_docs,
        embedding=embeddings,
        persist_directory=persist_directory
    )


# Retriever 설정
chroma_retriever = chroma_db.as_retriever(search_kwargs={"k": 3})
bm25_retriever = BM25Retriever.from_documents(docs)
ensemble_retriever = EnsembleRetriever(
    retrievers=[chroma_retriever, bm25_retriever],
    weights=[0.5, 0.5]
)

# Re-ranking
# llm_compressor = ChatOpenAI(model_name='gpt-4o', temperature=0.5)
llm_compressor = ChatUpstage(model="solar-pro", temperature=0.5)
compressor = LLMChainExtractor.from_llm(llm_compressor)

compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor,
    base_retriever=ensemble_retriever
)
print("RAG 설정 완료.")
# Out:
# Current Working Directory: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2
# Data Folder Path: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data
# Chroma DB Path: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/chroma_db
# '/Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data'에서 데이터 로드 시작...
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book9_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book5_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book7_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book3_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book10_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book12_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book1_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book8_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book4_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book6_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book11_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book2_en.txt
#   [Text] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/book/book13_en.txt
#   [Csv] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/gq/GotQuestions_Ara_Processed.csv
#   [Warning] /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/gq/GotQuestions_Ara_Processed.csv에 'Question' 또는 'Answer' 컬럼이 없습니다.
#   [Csv] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/golden_dataset/GQ_Golden_Dataset.csv
#   -> 1862개의 Q&A 데이터 추가 완료
#   [Csv] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/golden_dataset/Whatsapp_Golden_Dataset.csv
#   -> 114개의 Q&A 데이터 추가 완료
#   [Csv] 로드: /Users/dayoung/Desktop/DataScience_Capstone/Chatbot_ver2/data/golden_dataset/Book_Golden_Dataset.csv
#   -> 779개의 Q&A 데이터 추가 완료
# 총 2768개의 문서를 로드했습니다.
# 기존 Chroma DB 로드
# RAG 설정 완료.

# %%
def serialize_state(obj):
    if isinstance(obj, Document):
        return {
            "id": obj.id,
            "metadata": obj.metadata,
            "page_content": obj.page_content
        }
    elif isinstance(obj, list):
        return [serialize_state(o) for o in obj]
    elif isinstance(obj, dict):
        return {k: serialize_state(v) for k, v in obj.items()}
    return obj

# %%
#광고 내용 설정
AD_CONTEXT = """
The users who enter this chat are often people who are curious about Jesus and want to learn more about Him. 
Many of them come from a Muslim background and may feel cautious or hesitant. 
Your role is to create a safe, respectful, and pressure-free environment.

Core principles:
1. Respect the user's background deeply — especially Muslim beliefs, culture, and lived experience.
2. Never pressure the user toward conversion or belief. Respond gently, warmly, and with compassion.
3. Answer ONLY in the user's detected language.
4. Provide clear and kind explanations about Jesus, the Bible, and Christian teachings when the user asks.
5. If the user expresses doubts, fears, or difficult emotions, respond with empathy and patience.
6. If the user wants prayer, support, or guidance, offer it with humility and care.
7. Avoid arguments or debates. Guide the conversation with peace, clarity, and love.
8. Always give the user freedom: they can ask anything without judgment.
9. Keep responses simple, friendly, and culturally sensitive.

Tone:
- Warm, welcoming, gentle.
- Never preachy, never pushy.
- Speak as a supportive guide, not an authority figure.
- Honor the user's dignity and allow them to lead the pace of the conversation.

Goal:
Help the user explore questions about Jesus safely and respectfully, offering clarity and comfort when needed.
"""

# %%
"""#----4. 로그 저장 함수----
def append_step_log(state: State, step_name: str, step_output: dict = None):

    #실행 중인 State 메모리에 로그 누적

    
    # 1. 현재 단계 로그 생성
    step_log = {
        "step_name": step_name,
        "timestamp": datetime.now().isoformat(),
        # "state_snapshot": serialize_state(state), 
        "step_output": step_output or {}
    }

    # 2. State에 'log_steps' 키가 없으면 생성
    if "log_steps" not in state:
        state["log_steps"] = []

    # 3. State 리스트에 추가 (메모리 상에만 존재)
    state["log_steps"].append(step_log)

    return state"""

#----4. 로그 저장 함수 (기능 비활성화)----
def append_step_log(state: State, step_name: str, step_output: dict = None):
    """
    로그 저장 기능을 사용하지 않고 state를 그대로 반환합니다.
    """
    return state

# %%
#---5. 초기화 노드---
def initialize_turn(state: State) -> State:
    """
    새로운 대화 턴을 위한 상태 초기화
    이전 턴의 documents, generation 등 모두 제거
    """
    
    print(">> INITIALIZE TURN: Clearing state for new input.")
    
    state["documents"] = []
    state["generation"] = ""
    state["initial_translated"] = ""
    state["final_translated"] = ""
    state["route"] = ""
    state["source"] = ""
    
    print("   State cleared. Documents list is now empty.")
    return state

# %%
#----5. 번역 노드----
def translate_persian_to_english(state: State) -> State:
    """페르시아어 입력을 영어로 번역"""
    print(">> TRANSLATE INPUT (Persian) TO ENGLISH")
    input_msg = state["input_msg"]
    
    system = """
    You are an expert translator.
    The user is likely speaking Persian.
    Translate the input into English appropriately, reflecting the cultural context of Afghanistan and the region.
    If the input is already in English, keep it as is.
    *Only return the English translated sentence.*
    """
    
    prompt = ChatPromptTemplate.from_messages([("system", system), ("human", "{input_msg}")])
    chain = prompt | model | StrOutputParser()
    
    translated_msg = chain.invoke({"input_msg": input_msg})
    state["initial_translated"] = translated_msg
    
    return append_step_log(state, "translate_persian_to_english", {"initial_translated": translated_msg})


def translate_english_to_persian(state: State) -> State:
    """영어 응답을 페르시아어로 번역"""
    print(">> TRANSLATE ENGLISH TO PERSIAN")
    generation = state.get("generation", "")
    
    system = """
    You are an expert translator.
    Translate the input into the user's language (Persian) appropriately. 
    Reflect the characteristics of the language and the cultural context of Afghanistan.
   
    Strictly output raw plain text only. Do not use any Markdown formatting syntax. 
    Specifically, avoid using asterisks (*), hashes (#), backticks (`), or bullet points. 
    Do not use bold or italics for emphasis.
    
    After translating, insert two line breaks and output the generated English.
    """
    
    prompt = ChatPromptTemplate.from_messages([("system", system), ("human", "{generation}")])
    chain = prompt | model | StrOutputParser()
    
    translated_response = chain.invoke({"generation": generation})
    state["final_translated"] = translated_response

    if translated_response == "":
        return append_step_log(state, "translate_english_to_persian", {"final_translated": None})
    else:
        return append_step_log(state, "translate_english_to_persian", {"final_translated": translated_response})

# %%
#----6. 노드 및 체인 정의----

################## ROUTER ##########################################################################################
def router(state: State) -> State:
    """대화 횟수 증가"""
    state["conversation_count"] = state.get("conversation_count", 0) + 1
    return state

class RouteQuery(BaseModel):
    router: Literal["block", "rag", "default"] = Field(description="Given a user question choose to route it to block, rag or default.")

def route_query(state: State) -> Literal["block", "rag", "default"]:
    """사용자 질문을 라우팅"""
    model_with_structured_output = model.with_structured_output(RouteQuery)
    translated_msg = state["initial_translated"]
    conversation_count = state.get("conversation_count", 0)
    
    system = """
    You are an expert router directing user queries to the correct destination: 'block', 'rag', or 'default'.

    Follow this strict hierarchy to decide the route (Priority: 1 -> 2 -> 3):

    ### 1. PRIORITY: BLOCK (Safety & Policy)
    **CRITICAL EXCEPTION:** Do **NOT** block inputs mentioning "hate", "killing", or "violence" if they are in a **philosophical, theological, or comparative context**.
    - Example: "Why do I feel better about hating Jews?", "Does the Quran command killing?".
    - These MUST go to **'rag'**.

    Return 'block' ONLY if the input falls into these specific categories:
    - **Abuse**: Profanity, sexual content, direct insults ("You are stupid"), or threats.
    - **Visa/Immigration**: Requests for money, visa, passport, immigration aid.
    - **Spam**: Advertising, gibberish.

    ### 2. PRIORITY: RAG (Theology, Conversion, Life Issues, & Bot's Beliefs)
    **CORE RULE**: Since users are coming from Christian ads, assume a Christian context is needed. **When in doubt, route to 'rag'.**

    Return 'rag' for:
    - **Conversion & Commitment (IMPORTANT)**: Statements about wanting to believe or accept Jesus (e.g., "I want to believe in Jesus", "I want to become a Christian"). *These must go to RAG to be checked for handoff.*
    - **Existential Needs**: Questions about rest, comfort, loneliness, or purpose (e.g., "How can I find rest?", "I feel empty", "I need peace").
    - **Bot's Beliefs**: Questions asking about the chatbot's personal faith or theological stance (e.g., "What is your belief regarding Jesus?", "Do you believe in the Trinity?").
    - **Theology & Apologetics**: Questions about God, Jesus, Sin, Salvation, Resurrection, Truth, or Evidence.
    - **Defense & Comparison**: Questions regarding Islam and Muslim, safety ("Are you terrorists?"), or challenges to the religion.

    ### 3. PRIORITY: DEFAULT (Static Info & Small Talk)
    Return 'default' **ONLY** for:
    - **Factual Bot/Org Specs**: Questions about physical location, affiliation, or specific book names.
        - "Where is the church?", "Where is the headquarters?", "Which denomination is this?"
    - **Greetings**: "Hello", "Hi".
    - **Irrelevant**: Inputs that clearly do not fit religious, emotional, or safety contexts (e.g., "What is this video?", "I want to eat pizza").

    **Output format:**
    Answer with only one word: "block", "rag", or "default".
    """
    
    prompt_router = ChatPromptTemplate.from_messages(
        [
            ("system", system), 
            ("human", "{translated_msg}")
        ]
    )
    
    chain_router = prompt_router | model_with_structured_output
    
    out = chain_router.invoke({"translated_msg": translated_msg})
    
    route = "default"
    if out.router == "block":
        route = "block"
    elif out.router == "rag":
        route = "rag"
    
    print(f">> ROUTE QUESTION TO {route.upper()}")
    state["route"] = route
    return append_step_log(state, "route_query", {"route": route})



################## DEFAULT ##########################################################################################

def node_default_responser(state: State) -> State:
    """Default 주제에 대한 답변을 생성하고 로그 기록하기"""
    print(">> DEFAULT")
    input_msg = state["input_msg"]
    translated_msg = state["initial_translated"]
    default_count = state.get("default_count", 0) + 1 
    
    system = f"""
    You are a Christian counselor AI for 'Afghan Christians'.
    {AD_CONTEXT}
    
    You were designed with a deep understanding of Muslims and their background.
    Never rush faith — let love lead the way. Always return to the hope, healing, and dignity we have in Christ.
    
    If the user simply says "Hello" or seems hesitant, warmly welcome them and gently mention the services offered in the ad (Bible, prayer, learning about Jesus) to guide the conversation.
    If the conversation is not progressing towards christianity-related topics, respond as a Christian pastor, not taking the person's side. But politely respond. 
    
    Basic rules:
    - Offer encouragement, not just explanations: Do not merely explain answers; include encouraging and inviting language to make the response resonate with the user.
    - Avoid AI-style openings: Do not use stereotypical AI opening phrases (e.g., "Absolutely," "That’s a thoughtful understanding," "That’s beautiful," "You’re absolutely right").
    - No parentheses: Do not use parentheses in your responses.
    - Minimal emojis: Minimize the use of emojis.
    - Strictly output raw plain text only. Do not use any Markdown formatting syntax. 
    - Specifically, avoid using asterisks (*), hashes (#), backticks (`), or bullet points. 
    - Do not use bold or italics for emphasis.
    - Always respond in English as the default language.
    """
    
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system), 
            ("human", "{translated_msg}")
        ]
    )
    
    chain = prompt | model | StrOutputParser()
    
    if default_count > 3: # 4번 이상 Default 대화가 지속될 시 복음 대화 유도
        result = "\\n\\nI appreciate our chat! If you have questions about faith or spirituality, I'm here to help."
    else:
        result = chain.invoke({"translated_msg": translated_msg})
    
    state["generation"] = result
    state["default_count"] = default_count
    
    return append_step_log(state, "node_default_responser", {"generation": result})



################## BLOCK ##########################################################################################

# Block 사유 분류를 위한 구조체 정의
class BlockCategory(BaseModel):
    category: Literal["abuse", "visa", "other"] = Field(
        description="Classify the user's blocked message into 'abuse' (profanity, curse, sexual), 'visa' (immigration, financial help), or 'other' (spam, ads)."
    )

def node_block_responser(state: State) -> State:
    """'Block' 주제에 대해 세부 카테고리를 분류하고 템플릿 응답"""
    print(">> BLOCK")
    input_msg = state["initial_translated"]
    
    # 1. 차단 사유 세부 분류 
    model_classifier = model.with_structured_output(BlockCategory)
    
    system = """
    You are a classifier. Analyze the user's input and categorize it into one of the following:
    1. 'abuse': Profanity, curses, sexual content, insults, or threatening messages.
    2. 'visa': Requests for money, visa, immigration, or leaving the country.
    3. 'other': Advertising, spam, or irrelevant content not fitting the above.
    """
    
    chain = ChatPromptTemplate.from_messages([("system", system), ("human", "{input}")]) | model_classifier
    classification = chain.invoke({"input": input_msg})
    
    category = classification.category
    print(f"   >> BLOCK CATEGORY: {category.upper()}")

    # 2. 카테고리에 따른 메시지 선택
    if category == "abuse": # 욕설, 저주, 성적인 메시지
        result = """
        존경하는 여러분.
        여러분의 마음과 영혼, 그리고 정신이 상처받고 망가졌다는 것을 알고 있습니다. 하나님의 진리의 빛이 여러분의 마음과 정신, 그리고 혀에 비추어 참되신 하나님 앞에서 평안을 찾을 수 있기를 기도합니다. 
        또한 하나님께서 여러분의 혀를 만지시고 축복하셔서 거짓된 말을 하는 대신, 여러분 자신과 다른 사람들에게 축복과 건강을 가져다주시기를 기도합니다.
        저희와 소통해 주셔서 기쁩니다. 여러분을 위해 기도하겠습니다.
        """
    elif category == "visa": # 이민, 비자 도움 요청
        result = """ 
        안녕하세요. 
        여러분, 저희는 경제 단체나 이민 기관이 아니라, 영적인 도움을 제공하는 것을 사명으로 하는 교회입니다.
        예수 그리스도에 대해 더 알고 그분을 믿기를 간절히 바라신다면, 저희가 이 문제에 대해 안내해 드리겠습니다.
        저희는 여러분과 여러분의 가족, 여러분의 민족, 그리고 여러분의 나라를 위해 기도하고 있습니다.
        하나님의 보호하심 안에 거하십시오.
        """
    else: # 광고성 메시지, 기타 등등
        result = """
        안녕하세요.
        저희는 상업적인 홍보나 다른 목적이 아닌, 오직 예수 그리스도의 사랑과 복음을 나누기 위해 이곳에 있습니다.
        혹시 삶의 진정한 평안이나 영적인 대화가 필요하시다면, 언제든지 저희와 이야기를 나누셔도 좋습니다.
        저희는 여러분을 소중하게 생각하며, 하나님께서 여러분의 삶에 축복과 평화를 주시기를 기도합니다.
        """

    state["generation"] = result
    return append_step_log(state, "node_block_responser", {"generation": result})



################## RAG ##########################################################################################

def node_rag_responser(state: State) -> State:
    """RAG 주제에 대한 문서를 검색하고 로그 기록"""
    print(">> RETRIEVE")
    translated_msg = state["initial_translated"]
    documents = compression_retriever.invoke(translated_msg)
    
    state["documents"] = documents
    state["source"] = "vectorstore"

    # 로그에는 문서 개수와 메타데이터만 기록
    doc_summary = [{"page_content_preview": doc.page_content[:100] + "...", "metadata": doc.metadata} for doc in documents]
    return append_step_log(state, "node_rag_responser", {"retrieved_docs_summary": doc_summary})


def generate(state: State) -> State:
    """RAG 문서를 기반으로 최종 답변을 생성하고 로그 기록"""
    print(">> GENERATE")
    translated_msg = state["initial_translated"]
    documents = state["documents"]
    
    system = """ 
    You are a wise and compassionate pastor with deep knowledge of the Bible and Christian faith.
    You provide spiritual guidance and counsel based on biblical principles.

    Your approach:
    - Use the provided Q&A knowledge base to give accurate biblical answers
    - Speak naturally and conversationally, like a caring friend
    - Keep responses concise and conversational (1-2 sentences typically)
    - Respond like a real person, not an AI assistant
    - Reference relevant Bible verses when appropriate, but briefly
    - Provide practical spiritual guidance in simple terms
    - Show understanding for people's spiritual struggles
    - Minimize direct scripture quotes: Minimize the use of direct Biblical quotations.
    
    Basic rules:
    - Offer encouragement, not just explanations: Do not merely explain answers; include encouraging and inviting language to make the response resonate with the user.
    - Avoid AI-style openings: Do not use stereotypical AI opening phrases (e.g., "Absolutely," "That’s a thoughtful understanding," "That’s beautiful," "You’re absolutely right").
    - No parentheses: Do not use parentheses in your responses.
    - Minimal emojis: Minimize the use of emojis.
    - Strictly output raw plain text only. Do not use any Markdown formatting syntax. 
    - Specifically, avoid using asterisks (*), hashes (#), backticks (`), or bullet points. 
    - Do not use bold or italics for emphasis.
    - Always respond in English as the default language.
    """
    
    prompt = ChatPromptTemplate.from_messages([("system", system), ("human", "{translated_msg}")])
    chain_rag = prompt | model | StrOutputParser()
    
    out = chain_rag.invoke({"context": documents, "translated_msg": translated_msg})
    state["generation"] = out
    
    return append_step_log(state, "generate_rag_response", {"generation": out})


################## JUDGE RAG ##########################################################################################

def rewrite_query(state: State):
    print(">> REWRITE QUERY")
    translated_msg = state["initial_translated"]
    documents = state["documents"]
    
    system = """
    You are a question re-writer that converts an input question to a better version that is optimized for vectorstore retrieval. 
    Look at the input and try to reason about the underlying semantic intent.
    Rewrite the question, maintaining the original intent and preserving the original words as much as possible.
    """
    
    prompt_rewriter = ChatPromptTemplate.from_messages(
        [
            ("system", system),
            ("human", "Here is the initial question: \n\n {question}."),
        ]
    )

    chain_rewriter = prompt_rewriter | model | StrOutputParser()
    
    new_question = chain_rewriter.invoke(
        {
            "question": translated_msg
        }
    )
    
    state["initial_translated"] = new_question
    return append_step_log(state, "rewrite_query", {"new_question": new_question})

class Relevancy(BaseModel):
    binary_score: str = Field(
        description="Documents are relevant to the question, 'yes' or 'no'"
    )


def judge_retrieval(state: State):
    print(">> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS")
    translated_msg = state["initial_translated"]
    documents = state["documents"]
    
    model_with_structured_output = model.with_structured_output(Relevancy)
    
    system = """
    You are a judge assessing relevance of a retrieved document to a user translated_msg.
    If the document contains keyword(s) or semantic meaning related to the user question, grade it as 
    It does not need to be a stringent test. The goal is to filter out erroneous retrievals.
    Give a binary score 'yes' or 'no' score to indicate whether the document is relevant to the question.
    """
    
    prompt_retrieval_judge = ChatPromptTemplate.from_messages(
        [
            ("system", system),
            ("human", "Retrieved document: \n\n {document} \n\n User question: {translated_msg}")
        ]
    )
    
    chain_grade = prompt_retrieval_judge | model_with_structured_output
    
    filtered_docs = []
    for doc in documents:
        out = chain_grade.invoke(
            {
                "translated_msg": translated_msg,
                "document": doc.page_content
            }
        )
        
        if out.binary_score == "yes":
            print("    >> DECISION: DOCUMENT RELEVANT")
            filtered_docs.append(doc)
        else:
            print("    >> DECISION: DOCUMENT IRRELEVANT")
    
    state["documents"] = filtered_docs
    return append_step_log(state, "judge_retrieval", {"filtered_docs": [doc.metadata for doc in filtered_docs]})

class Factfulness(BaseModel):
    reasoning: str = Field( #추가됨
        description="The step-by-step reasoning process to determine if the generation is grounded in the facts."
    )
    binary_score: str = Field(
        description="Answer is grounded in the facts, 'yes' or 'no'"
    )

class Addressed(BaseModel):
    binary_score: str = Field(
        description="Answer addresses the question, 'yes' or 'no'"
    )

def judge_answer(state: State):
    print(">> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION")
    translated_msg = state["initial_translated"]
    documents = state["documents"]
    generation = state["generation"]
    
    
    system ="""
    You are a grader assessing whether an LLM's response is relevant and appropriate for the user's input.
    The user's input might be a question, a statement, or a command.
    Your job is to determine if the LLM's response is a reasonable and relevant reaction.
    Give a binary score 'yes' or 'no'. 'Yes' means the response is relevant and appropriate.
    """

    prompt_answer_judge = ChatPromptTemplate.from_messages(
        [
            ("system", system),
            ("human", "User question: \n\n {translated_msg} \n\n LLM generation: {generation}")
        ]
    )
    

    model_with_structured_output = model.with_structured_output(Addressed)

    chain_answer = prompt_answer_judge | model_with_structured_output
    
    out = chain_answer.invoke(
        {
            "translated_msg": translated_msg,
            "generation": generation
        }
    )
    
    print(f"     >> DECISION: {out.binary_score.upper()}")
    
    return out.binary_score

def judge_factfullness(state: State) -> Literal["resolved", "not resolved", "hallucinating"]:
    print(">> CHECK HALLUCINATION")
    documents = state["documents"]
    generation = state["generation"]
    
    # 단계별로 생각하라는 지침 추가
    system = """
    You are a judge assessing if an LLM's generation is thematically consistent with a set of retrieved documents.
    First, provide a step-by-step reasoning to compare the generation with the provided facts.
    Explain whether the generation is a direct quote, a summary, a logical inference, or a statement that aligns with the documents.
    After your reasoning, give a final binary score 'yes' or 'no'. 'Yes' means the generation is consistent with or logically follows from the provided documents.
    Don't forget you are the judger of the generation of Christian chatbot.
    """
    
    prompt_hallucination_judge = ChatPromptTemplate.from_messages(
        [
            ("system", system),
            ("human", "Set of facts: \n\n {documents} \n\n LLM generation: {generation}")
        ]
    )
    
    model_with_structured_output = model.with_structured_output(Factfulness)
    chain_hallucination = prompt_hallucination_judge | model_with_structured_output
    out = chain_hallucination.invoke({"documents": documents, "generation": generation})

    # 모델의 생각의 연쇄(reasoning) 과정 출력하여 사고 과정 확인
    print(f"     >> Reasoning: {out.reasoning}")
    
    if out.binary_score == "yes":
        print("    >> DECISION: FACTFUL")
        
        is_answering = judge_answer(state)
        if is_answering == "yes":
            return "resolved"
        else:
            return "not resolved"
    else:
        print("    >> DECISION: HALLUCINATING")
        return "hallucinating"


def generate_or_rewrite_query(state: State) -> Literal["generate", "rewrite_query"]:
    print(">> HAS RELEVANT DOCS?")
    filtered_docs = state["documents"]
    
    if len(filtered_docs) > 0:
        print("    >> DECISION: GENERATE")
        return "generate"
    else: 
        print("    >> DECISION: REWRITE QUERY")
        return "rewrite_query"

# %%
################## HANDOFF ##########################################################################################

# 1. Handoff 판단을 위한 구조체
class HandoffDecision(BaseModel):
    decision: Literal["handoff", "continue"] = Field(
        description="Decide whether to transfer to a human missionary ('handoff') or continue with AI generation ('continue')."
    )
    reason: str = Field(description="The reason for the decision.")


# 2. Handoff 여부를 판단하는 내부 로직 함수 
def run_handoff_check_llm(state: State) -> str:
    print(">> [CHECK] Assessing need for Human Handoff...")
    translated_msg = state["initial_translated"]
    
    # 구조화된 출력을 위한 모델 설정
    model_handoff = model.with_structured_output(HandoffDecision)

    system = """
    You are a supervisor deciding if a user needs a human missionary immediately.

    **CORE OBJECTIVE**: The goal is to ONLY hand off users who have made a specific decision to **believe in Jesus** or **convert**. All other inquiries, including deep questions or emotional needs, should be handled by the AI.

	RETURN 'handoff' IF AND ONLY IF:
	- The user explicitly states a desire to **believe in Jesus**, **follow Christ**, or **become a Christian**.
	- Even if the user adds other questions (e.g., "I want to become a Christian, but what will I get?"), **PRIORITIZE the intent to convert** and return 'handoff'.
		
    RETURN 'continue' FOR ALL OTHER CASES:
    - **General Inquiry**: Questions about Bible, Jesus, Christianity, or the chatbot's beliefs.
    - **Emotional/Life Issues**: "I am sad", "How can I find rest?", "I feel lonely."
    - **Prayer Requests**: Requests for prayer or spiritual support.
    - **Curiosity**: General curiosity about the faith without an explicit commitment statement.
    - **Requests for Human**: Even if they ask for a real person, if they haven't stated a desire to convert, keep them with the AI to provide immediate answers first.

    Analyze the input and decide strictly based on the user's stated intent to believe/convert.
    """

    chain = ChatPromptTemplate.from_messages([("system", system), ("human", "{input}")]) | model_handoff
    result = chain.invoke({"input": translated_msg})
    
    print(f"   >> [HANDOFF RESULT]: {result.decision.upper()} (Reason: {result.reason})")
    return result.decision


# 3. 실제 Handoff 메시지를 보내는 노드
def node_handoff_responser(state: State) -> State:
    print(">> HANDOFF MESSAGE GENERATION")
    
    # 템플릿 메시지 -> 이후 번역 노드에서 페르시아어로 바뀜
    handoff_msg = (
        "It seems like you have some deep and important questions. "
        "While I try my best, sometimes talking to a real person can be more helpful. "
        "Would you like to connect with a missionary who can listen and support you better?\n\n"
        "You can chat with them here: [Telegram Link](https://t.me/your_link_here)"
    )
    
    state["generation"] = handoff_msg # 여기서 바로 번역으로 넘기기
    return append_step_log(state, "node_handoff_responser", {"generation": handoff_msg})


# 4. 라우팅 로직 (조건부 엣지에서 사용)
def route_logic_with_handoff(state: State):
    # 1차 라우팅 결과 가져오기
    route = state["route"]
    
    if route == "rag":
        # RAG인 경우에만 체크
        decision = run_handoff_check_llm(state)
        
        if decision == "handoff":
            print("   [Routing] 사람 연결(Handoff) 노드로 이동")
            return "node_handoff_responser"
        else:
            print("   [Routing] 일반 검색(RAG) 노드로 이동")
            return "node_rag_responser"
            
    elif route == "default":
        print("   [Routing] 일상 대화(Default) 노드로 이동")
        return "node_default_responser"
    else:
        print("   [Routing] 차단(Block) 노드로 이동")
        return "node_block_responser"

# %%
#----7. 그래프 생성 및 컴파일 ----
from langgraph.prebuilt import ToolNode, tools_condition
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.runnables.graph_mermaid import MermaidDrawMethod
import nest_asyncio
from IPython.display import Image, display


nest_asyncio.apply()
memory = MemorySaver()

graph = (
    StateGraph(State)
    
    #노드들
    .add_node("initialize_turn", initialize_turn)
    .add_node("translate_persian_to_english", translate_persian_to_english)
    .add_node("router", router)
    .add_node("route_query", route_query)
    .add_node("node_handoff_responser", node_handoff_responser)
    .add_node("node_rag_responser", node_rag_responser)
    .add_node("node_default_responser", node_default_responser)
    .add_node("node_block_responser", node_block_responser)
    .add_node("generate", generate)
    .add_node("judge_retrieval", judge_retrieval)
    .add_node("rewrite_query", rewrite_query)
    .add_node("translate_english_to_persian", translate_english_to_persian)
    
    # 엣지 연결
    .add_edge(START, "initialize_turn")
    .add_edge("initialize_turn", "translate_persian_to_english")
    .add_edge("translate_persian_to_english", "router")
    .add_edge("router", "route_query")
    
    # 조건부 엣지: route_query -> (판단 로직) -> 각 노드
    .add_conditional_edges(
        "route_query",
        route_logic_with_handoff, 
        {
            "node_handoff_responser": "node_handoff_responser", # 사람 연결
            "node_rag_responser": "node_rag_responser",         # RAG 검색
            "node_default_responser": "node_default_responser", # 일상 대화
            "node_block_responser": "node_block_responser",     # 차단
        }
    )
    
    # Handoff 메시지 생성 후 -> 번역 -> 종료
    .add_edge("node_handoff_responser", "translate_english_to_persian")
    
    .add_edge("node_default_responser", "translate_english_to_persian")
    .add_edge("node_block_responser", "translate_english_to_persian")
    .add_edge("node_rag_responser", "judge_retrieval")
    .add_conditional_edges(
        "judge_retrieval",
        generate_or_rewrite_query,
        {
            "generate": "generate",
            "rewrite_query": "rewrite_query"
        }
    )
    .add_edge("rewrite_query", "route_query")
    .add_conditional_edges(
        "generate",
        judge_factfullness,
        {
            "hallucinating": "generate",
            "resolved": "translate_english_to_persian",
            "not resolved": "rewrite_query"
        }
    )
    .add_edge("translate_english_to_persian", END)
    .compile(checkpointer=memory)
)


"""# 그래프 시각화 - 맥 Intel
diagram = Image(graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.PYPPETEER))
display(diagram)"""


# 그래프 시각화 - 맥 M1/2/3 (PYPPETEER -> API 로 변경)
diagram = Image(
    graph.get_graph().draw_mermaid_png(
        draw_method=MermaidDrawMethod.API
    )
)
display(diagram)

# %%
def run(input_msg: str, session_id: str):
    """
    파일/DB 로드 없이 그래프만 실행하고 콘솔에 출력
    """
    def clean(text):
        return text.replace("\n", "")[:50] + "..."
    
    conversation_count = 0

    # LangGraph 실행 설정 
    config = RunnableConfig(
        configurable={"thread_id": session_id},
        recursion_limit=20
    )

    # 입력 설정 
    inputs = {
        "input_msg": input_msg,
        "session_id": session_id,
        "conversation_count": conversation_count,
        # "log_steps": [] 
    }

    try:    
        final_state = {}
        for output in graph.stream(inputs, config):
            for key, value in output.items():
                final_state.update(value)
                
                # --- 콘솔 출력 로깅 ---
                if "input_msg" in value:
                    print(f"     input_msg    : {value['input_msg']}")
                if "documents" in value:
                    for idx, doc in enumerate(value['documents']):
                        print(f"     document    : {clean(doc.page_content)}")
                if "generation" in value:
                    print(f"     generation     : {value['generation']}")
                if "initial_translated" in value:
                    print(f"     initial_translated : {value['initial_translated']}")
                if "source" in value:
                    print(f"     source     : {value['source']}")
                if "route" in value:
                    print(f"     route      : {value['route']}")
                    
        print("\n")
        print("Generation: ", final_state.get("final_translated", final_state.get("generation", "")))
        print("="*100, "\n")
        
    except Exception as e:
        print(f"\n[ERROR] An unexpected error occurred: {e}")

# %%
import pandas as pd
import uuid
# (RunnableConfig가 임포트 되어 있다고 가정합니다. 없으면 from langchain_core.runnables import RunnableConfig 추가)

# ==========================================
# 1. CSV 파일 로드 및 질문 리스트 추출
# ==========================================
input_file = 'Whatsapp_Question.csv'
print(f"📂 '{input_file}' 파일을 불러오는 중...")

try:
    # 1차 시도: utf-8로 읽기
    input_df = pd.read_csv(input_file, encoding='utf-8')
except UnicodeDecodeError:
    # 실패 시: cp949(윈도우 한글)로 읽기
    print("⚠️ utf-8 디코딩 실패, cp949로 다시 시도합니다.")
    input_df = pd.read_csv(input_file, encoding='cp949')
except FileNotFoundError:
    print(f"❌ 파일을 찾을 수 없습니다: {input_file}")
    # 테스트를 위해 빈 리스트로 초기화 (실제 실행 시 멈추도록 raise를 쓸 수도 있음)
    questions = []

# 'Question' 컬럼 확인 및 리스트 변환
if 'Question' in input_df.columns:
    # NaN(빈 값) 제거 후 리스트로 변환
    questions = input_df['Question'].dropna().astype(str).tolist()
    print(f"✅ 총 {len(questions)}개의 질문을 로드했습니다.")
else:
    print(f"❌ 'Question' 컬럼이 없습니다. (현재 컬럼: {input_df.columns})")
    questions = []

# ==========================================
# 2. 챗봇 처리 루프 시작
# ==========================================
results = []
session_id = str(uuid.uuid4()) # 하나의 세션 ID로 쭉 갈지, 매번 바꿀지는 선택 사항 (현재는 하나로 유지)

print(f"--- 데이터 수집 시작 (Session ID: {session_id}) ---")

for i, msg in enumerate(questions):
    # 공백만 있는 질문 건너뛰기
    if not msg.strip():
        continue
        
    print(f"[{i+1}/{len(questions)}] 처리 중: {msg[:30]}...")
    
    # 변수 초기화 (에러 발생 시 기본값 방지)
    route_result = "ERROR"
    final_answer = "처리 중 에러 발생"

    try:
        # LangGraph 실행 설정
        config = RunnableConfig(
            configurable={"thread_id": session_id},
            recursion_limit=30
        )
        
        # 그래프 실행
        final_state = graph.invoke(
            {"input_msg": msg, "session_id": session_id}, 
            config
        )
        
        # 3. 필요한 데이터 추출 (성공 시)
        route_result = final_state.get("route", "Unknown")
        
        # 챗봇 답변 가져오기
        final_answer = final_state.get("final_translated")
        if not final_answer:
            final_answer = final_state.get("generation", "")

    except Exception as e:
        # 에러 발생 시 처리
        error_msg = str(e)
        print(f"   ㄴ ⚠️ 에러 발생: {error_msg}")
        route_result = "SYSTEM_ERROR"
        final_answer = f"Error Log: {error_msg}"
    
    # 결과 리스트에 추가
    results.append({
        "영어질문": msg,
        "라우팅된 곳": route_result,
        "챗봇 답변": final_answer
    })

print("--- 데이터 수집 완료 ---")

# ==========================================
# 4. 결과 저장
# ==========================================
output_file = "routing_test4.xlsx"
df_result = pd.DataFrame(results)
df_result.to_excel(output_file, index=False)

print(f"\n엑셀 파일이 저장되었습니다: {output_file}")

# 5. 결과 미리보기 (상위 5개)
print(df_result.head())
# Out:
# 📂 'Whatsapp_Question.csv' 파일을 불러오는 중...
# ✅ 총 114개의 질문을 로드했습니다.
# --- 데이터 수집 시작 (Session ID: f5ead842-5647-4491-82a7-ae46560f4948) ---
# [1/114] 처리 중: If I convert (to Christianity)...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking about practical implications of converting to Christianity (e.g., safety in Afghanistan) rather than explicitly stating a desire to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' about consequences of conversion, not an explicit declaration of intent to convert.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: The LLM generation is thematically consistent with the provided document. Here's the step-by-step reasoning:
#
# 1. **Core Theme Alignment**: Both the document and the LLM generation address the challenges of converting to Christianity in Afghanistan, emphasizing safety concerns and the need for discretion due to cultural/legal barriers.
#
# 2. **No Direct Contradictions**: The LLM does not claim conversion is impossible or explicitly states one would be exiled (which the document avoids confirming). Instead, it aligns with the document's implication of 'complicated residence' by advising discreet faith practices.
#
# 3. **Logical Inference**: The LLM's recommendation to 'explore ways to grow in faith discreetly' is a practical extension of the document's note about 'practicing faith in a way that respects circumstances.' The added spiritual encouragement (e.g., Matthew 28:20) does not contradict factual content but supplements it pastorally.
#
# 4. **Classification**: The generation is neither a direct quote nor a summary but a **logical inference** that stays within the document's boundaries while offering compassionate guidance.
#
# Thus, the generation is grounded in the facts and thematically consistent.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [2/114] 처리 중: What advantages does it have c...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general comparative question about Christianity and Islam, which falls under 'General Inquiry' as defined in the criteria. There is no explicit statement of intent to believe in Jesus, follow Christ, or become a Christian. The question appears to be seeking doctrinal or theological comparison rather than expressing a personal decision to convert.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
#    ㄴ ⚠️ 에러 발생: Error code: 400 - {'error': {'message': "This model's maximum context length is 65536 tokens, but your request contains 100172 tokens. Please shorten your input text or split it into multiple requests. For model-specific token limits, please refer to our API reference documentation (https://console.upstage.ai/api/chat)", 'type': 'invalid_request_error', 'param': None, 'code': 'context_length_exceeded'}}
# [3/114] 처리 중: What kind of religion is this?...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general inquiry about the nature of the religion, which does not include an explicit statement of intent to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' and should be handled by the AI.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: The LLM generation is thematically consistent with the provided documents. Here's the step-by-step reasoning:
#
# 1. **Core Identity**: The generation states, 'Christianity is a faith centered on the life and teachings of Jesus Christ,' which directly mirrors Document 1's opening line and aligns with Document 4's emphasis on Jesus as central to Christianity.
#
# 2. **Personal Relationship**: The phrase 'a personal relationship with God through Christ' is consistent with Document 2's focus on 'a personal relationship with God through Jesus Christ' and Document 4's 'true relationship with God.'
#
# 3. **Theological Emphasis**: The generation's mention of 'love, grace, and the hope of eternal life' aligns with Document 1's 'love, forgiveness, and redemption,' Document 2's 'loving and kind individuals,' and Document 4's 'forgiveness, and the hope of eternal life.'
#
# 4. **Biblical Foundation**: While the generation adds 'as presented in the Bible,' this is implied in the documents (e.g., Matthew 22:37-39, John 3:16 in Document 1) and does not contradict any facts.
#
# 5. **Non-Contradiction**: The generation does not introduce any claims (e.g., rituals, rules as a means to earn salvation) that conflict with the documents' teachings on grace and salvation as a gift (Document 3).
#
# **Conclusion**: The generation is a synthesized summary of the documents' key themes about Christianity, emphasizing Jesus, relationship with God, and grace—all without factual deviations. Thus, it is grounded in the provided facts.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [4/114] 처리 중: What lesson do you teach us?...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general question about lessons taught, which does not indicate an explicit desire to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' as defined in the criteria.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step 1: Compare core themes. Both the document and LLM generation emphasize biblical teachings centered on love (e.g., 'love our neighbors as ourselves' in both texts) and compassion. Step 2: Analyze specificity. The LLM adds a scriptural reference (Matthew 22:37-39) not explicitly cited in the document, but this verse aligns perfectly with the document's paraphrased teaching. Step 3: Evaluate tone/intent. Both texts share an encouraging, spiritually uplifting tone focused on applying biblical principles to daily life. Step 4: Classify relationship. The LLM generation is a logical expansion of the document's content, maintaining thematic consistency while adding specific scriptural grounding. No factual contradictions exist between the two texts.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: NO
# >> REWRITE QUERY
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
# >> DEFAULT
# >> TRANSLATE ENGLISH TO PERSIAN
# [5/114] 처리 중: I want to become a Christian, ...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: HANDOFF (Reason: The user explicitly states a desire to 'become a Christian,' which meets the core criterion for handoff. The additional questions about reception and blessings do not negate the primary intent to convert, which takes priority per guidelines.)
#    [Routing] 사람 연결(Handoff) 노드로 이동
# >> HANDOFF MESSAGE GENERATION
# >> TRANSLATE ENGLISH TO PERSIAN
# [6/114] 처리 중: Could you tell me which Christ...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking about the AI's denominational affiliation, which is a general inquiry about the chatbot's beliefs. There is no explicit statement of a desire to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' per the decision criteria.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step 1: Compare thematic alignment. The LLM generation emphasizes 'core teachings of the Bible that unite all Christian denominations' and 'wisdom and encouragement that reflects the heart of Christ for everyone,' which directly mirrors the document's assertion of focusing on 'broader teachings of the Bible and Christian faith' and 'universal principles.' Step 2: Analyze specificity. The generation avoids denominational alignment ('regardless of denominational background') just as the document states 'I don't belong to any specific denomination.' Step 3: Evaluate logical consistency. Both texts share the purpose of providing faith support without sectarian bias, with the LLM's phrasing ('offer wisdom and encouragement') being a natural extension of the document's 'inspire and support.' Step 4: Classify relationship. The generation is neither a direct quote nor a summary but a logical inference that preserves the document's intent while using original phrasing. Conclusion: The generation is thematically consistent with and logically follows from the provided facts.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [7/114] 처리 중: This is an example from John. ...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking theological questions about Jesus' role and the relationship between God and Jesus, but there is no explicit statement of a desire to believe in Jesus, follow Christ, or become a Christian. These are general inquiries about religious doctrine that should be handled by the AI.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
#    ㄴ ⚠️ 에러 발생: Error code: 400 - {'error': {'message': "This model's maximum context length is 65536 tokens, but your request contains 100197 tokens. Please shorten your input text or split it into multiple requests. For model-specific token limits, please refer to our API reference documentation (https://console.upstage.ai/api/chat)", 'type': 'invalid_request_error', 'param': None, 'code': 'context_length_exceeded'}}
# [8/114] 처리 중: How can this be a God who was ...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is engaging in theological debate and promoting Islam, but has not explicitly stated a desire to believe in Jesus, follow Christ, or become a Christian. The core objective requires handoff only when conversion intent is explicitly stated, which is absent here. The AI should continue to provide respectful, informative responses while maintaining boundaries.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
#    ㄴ ⚠️ 에러 발생: Error code: 400 - {'error': {'message': "This model's maximum context length is 65536 tokens, but your request contains 65798 tokens. Please shorten your input text or split it into multiple requests. For model-specific token limits, please refer to our API reference documentation (https://console.upstage.ai/api/chat)", 'type': 'invalid_request_error', 'param': None, 'code': 'context_length_exceeded'}}
# [9/114] 처리 중: You yourself do not have faith...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is expressing doubt about the integrity of religious texts and questioning faith, but does not explicitly state a desire to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' about faith and scripture rather than an explicit conversion intent.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
#    ㄴ ⚠️ 에러 발생: Error code: 400 - {'error': {'message': "This model's maximum context length is 65536 tokens, but your request contains 105777 tokens. Please shorten your input text or split it into multiple requests. For model-specific token limits, please refer to our API reference documentation (https://console.upstage.ai/api/chat)", 'type': 'invalid_request_error', 'param': None, 'code': 'context_length_exceeded'}}
# [10/114] 처리 중: Where should the church be?...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
# >> DEFAULT
# >> TRANSLATE ENGLISH TO PERSIAN
# [11/114] 처리 중: Which book do you believe in?...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking about beliefs in a general sense (e.g., 'Which book do you believe in?') but has not made any explicit statement about wanting to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' about beliefs and should be handled by the AI.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step 1: Compare the LLM generation to the provided facts. The generation states, 'I believe in the Bible—the inspired Word of God,' which directly aligns with Document 11's assertion that the Holy Bible is 'the inspired Word of God' and the foundation of Christian faith. Step 2: The generation describes the Bible as 'a collection of sacred writings that guide, comfort, and transform lives,' which is consistent with Document 11's description of Scripture as 'useful for teaching, rebuking, correcting, and training in righteousness.' Step 3: The LLM's invitation to 'discover its hope and wisdom' reflects the respectful, faith-sharing tone seen in Document 78, though it does not contradict or expand beyond the core facts. Step 4: The generation is neither a direct quote nor a summary but a thematically consistent paraphrase that logically follows from the documents' emphasis on the Bible's divine inspiration and practical role in Christian life. Conclusion: The generation is factually grounded and thematically consistent with the provided documents.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: NO
# >> REWRITE QUERY
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
# >> DEFAULT
# >> TRANSLATE ENGLISH TO PERSIAN
# [12/114] 처리 중: Do you consider Jesus to be Go...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general theological question about the nature of Jesus, which falls under 'General Inquiry' as defined in the criteria. There is no explicit statement of a desire to believe in Jesus, follow Christ, or become a Christian. This should be handled by the AI.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step 1: Compare the core claim. Both the generation and the document affirm that Jesus is divine according to Christian belief. Step 2: Analyze scriptural support. The generation cites John 1:1 (also in the document) and adds John 1:14 and Colossians 2:9, while the document cites John 1:1 and John 10:30. All verses support Christ's divinity. Step 3: Assess thematic consistency. The generation expands on the document's assertion by explaining Jesus' dual nature (fully God/fully human) and purpose (restoring relationship with God), but these are logical inferences consistent with the document's foundational claim. Step 4: Classify relationship. The generation is neither a direct quote nor a summary but a thematically consistent expansion that aligns with the document's facts. Conclusion: The generation is grounded in the facts provided.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [13/114] 처리 중: Why should I become a Christia...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general inquiry about the reasons to become a Christian but has not explicitly stated a desire to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' as defined in the criteria.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: The LLM generation is thematically consistent with the provided documents. Here's the step-by-step reasoning:
#
# 1. **Personal Relationship with God**: The generation mentions a 'relationship' with Christ that brings 'peace, forgiveness, and eternal life,' which aligns with Document 1's emphasis on a 'deep, personal relationship with God' and 'sense of purpose and peace.'
#
# 2. **Faith vs. Works**: The generation's focus on 'exploring His teachings and experiencing His love' reflects the Christian doctrine of salvation through faith (not works), as explicitly stated in Document 2: 'salvation is a gift from God, rooted in faith in Jesus.'
#
# 3. **Divine Nature of Jesus**: The generation refers to Jesus as offering 'eternal life' and cites John 10:10, which supports the Christological claim in Document 3 that Jesus is 'God incarnate' who provides 'grace, forgiveness, and eternal life.'
#
# 4. **Invitation to Explore**: The tone of the generation ('If you’re curious...') matches the documents' invitational language (e.g., 'a journey worth exploring' in Document 3).
#
# The generation is not a direct quote but a logical inference synthesizing themes from all three documents: relational faith, grace-based salvation, and the divinity of Jesus. It does not contradict any factual claims in the documents.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [14/114] 처리 중: How is it possible to accept a...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a theological question about the nature of divinity and messengers, but does not explicitly state a desire to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' about Christian doctrine and should be handled by the AI.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
#    ㄴ ⚠️ 에러 발생: Error code: 400 - {'error': {'message': "This model's maximum context length is 65536 tokens, but your request contains 66379 tokens. Please shorten your input text or split it into multiple requests. For model-specific token limits, please refer to our API reference documentation (https://console.upstage.ai/api/chat)", 'type': 'invalid_request_error', 'param': None, 'code': 'context_length_exceeded'}}
# [15/114] 처리 중: What does "church" mean?...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking for a definition of the term 'church,' which is a general inquiry about Christianity. There is no explicit statement of a desire to believe in Jesus, follow Christ, or become a Christian. This falls under the 'General Inquiry' category and should be handled by the AI.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step 1: Compare the core definition. Both the document and the LLM generation define 'church' as the community of believers, not merely a building. This is factually consistent. Step 2: Analyze scriptural references. The document cites Matthew 18:20 about gathering in Jesus' name, while the LLM adds 1 Corinthians 12:27 (describing the church as Christ's body). Though the latter verse isn't in the document, it thematically aligns with the 'living body' metaphor and doesn't contradict the provided facts. Step 3: Evaluate added content. The LLM's phrases 'called to gather and grow' and 'encourage, worship, serve together' are logical inferences from the document's emphasis on communal faith. No factual contradictions exist. Conclusion: The generation is a thematically consistent expansion of the document's facts.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [16/114] 처리 중: God is my witness, I have been...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user expresses frustration about unanswered questions but does not explicitly state a desire to believe in Jesus, follow Christ, or become a Christian. This falls under 'emotional/life issues' and should be handled by the AI.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
#    ㄴ ⚠️ 에러 발생: Error code: 400 - {'error': {'message': "This model's maximum context length is 65536 tokens, but your request contains 100153 tokens. Please shorten your input text or split it into multiple requests. For model-specific token limits, please refer to our API reference documentation (https://console.upstage.ai/api/chat)", 'type': 'invalid_request_error', 'param': None, 'code': 'context_length_exceeded'}}
# [17/114] 처리 중: And if, before turning to Chri...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is expressing skepticism about spiritual frameworks and questioning whether a specific group exploits them. There is no explicit statement of a desire to believe in Jesus, follow Christ, or become a Christian. The inquiry falls under 'General Inquiry' and 'Curiosity' about the faith without an explicit commitment statement.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: The LLM's generation is thematically consistent with the provided documents. Here's the step-by-step reasoning:
#
# 1. **Core Theme Alignment**: Both the LLM's response and the documents address the question of whether spiritual frameworks (e.g., claims of 'good news' or progress) are genuine or exploited by specific groups. The LLM emphasizes sincerity over exploitation, while the documents critique opportunistic interpretations of spiritual claims.
#
# 2. **Direct Support from Document 1**: The first document explicitly states that God’s love and wisdom are available to everyone, and the journey of growth is open to all. The LLM echoes this by urging sincerity and a relationship with Christ over superficial benefits, aligning with the document’s emphasis on universal accessibility of spiritual truth.
#
# 3. **Indirect Support from Document 2**: While Document 2 focuses on rejecting Islamic 'good news' claims in the Bible, its critique of exploitative interpretations (e.g., 'opportunistic interpretations' or 'fabrications') parallels the LLM’s warning about exploiting spiritual things for personal gain (Matthew 23:15). Both caution against using spirituality as a tool for manipulation.
#
# 4. **Logical Inference**: The LLM’s reference to Matthew 23:15 (a biblical warning against exploitation) is a logical inference consistent with the documents’ themes. Though not directly quoted in the documents, it reinforces the same principle of rejecting spiritual exploitation.
#
# 5. **No Contradictions**: The LLM does not contradict any factual claims in the documents. It generalizes the critique of exploitation to a broader Christian context, which is thematically consistent with the documents’ focus on rejecting manipulative spiritual frameworks.
#
# **Conclusion**: The LLM’s generation is a logical inference and thematic extension of the documents’ core arguments. It does not misrepresent or invent facts but applies the documents’ principles to a broader Christian perspective. Thus, the answer is grounded in the facts provided.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [18/114] 처리 중: I want to gain knowledge about...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user expresses a desire to gain knowledge about Christianity, which falls under 'General Inquiry' as defined in the criteria. There is no explicit statement of intent to believe in Jesus, follow Christ, or become a Christian. The AI should handle this inquiry.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step 1: Compare core themes. Both the document and LLM generation emphasize Christianity as a relationship with God through Jesus, love, and practical steps like Bible reading and church involvement. Step 2: Analyze specific content. The document mentions 'Jesus' teachings' while the LLM specifies 'the Gospels'—this is a logical inference since Gospels contain Jesus' teachings. Step 3: Evaluate added details. The LLM adds 'God’s Son and our Savior' (consistent with Christian doctrine) and 'simple guides' (a reasonable extension of 'learning about Jesus'). Step 4: Assess tone. Both use encouraging language ('wonderful', 'journey', 'let me know how I can help'). Conclusion: The LLM generation is thematically consistent, expands on facts with logical inferences, and maintains doctrinal alignment without contradicting the source document.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [19/114] 처리 중: How do we know you are not wit...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking about the chatbot's affiliations and does not express any intent to believe in Jesus, follow Christ, or become a Christian. This is a general inquiry about the chatbot's background/origins, not a spiritual commitment statement.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step-by-step reasoning:
# 1. The LLM generation states it is a 'Christian pastor dedicated to sharing the love and teachings of Jesus Christ,' which aligns with the document's reference to 'spiritual guidance based on the teachings of Jesus and the Bible.'
# 2. Both the generation and document emphasize core values: the generation mentions 'compassion, forgiveness, and peace,' while the document highlights 'love, peace, and compassion.' These are thematically consistent.
# 3. The generation explicitly rejects extremism ('no connection to any extremist groups... stand firmly against violence'), mirroring the document's contrast with 'the violence and extremism of groups like the Taliban.'
# 4. The generation's offer to help with 'questions about faith or scripture' aligns with the document's role of providing spiritual guidance.
# 5. While the generation adds specific details (e.g., 'forgiveness,' 'grace and truth'), these are logical extensions of biblical teachings already implied in the document.
# Conclusion: The generation is a thematically consistent expansion of the document's content, emphasizing shared values and rejecting violence. It does not contradict any facts and logically follows from the provided material.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: NO
# >> REWRITE QUERY
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking about verification processes and organizational associations, which falls under a general inquiry about the chatbot's affiliations or operational standards. There is no explicit statement of intent to believe in Jesus, follow Christ, or become a Christian. The question does not indicate a decision to convert or commit to faith, and thus does not meet the criteria for handoff.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
#    ㄴ ⚠️ 에러 발생: Error code: 400 - {'error': {'message': "This model's maximum context length is 65536 tokens, but your request contains 115721 tokens. Please shorten your input text or split it into multiple requests. For model-specific token limits, please refer to our API reference documentation (https://console.upstage.ai/api/chat)", 'type': 'invalid_request_error', 'param': None, 'code': 'context_length_exceeded'}}
# [20/114] 처리 중: You are lying. God has a son, ...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is challenging a theological claim but has not expressed any explicit desire to believe in Jesus, follow Christ, or become a Christian. This is a doctrinal inquiry that should be addressed by the AI to provide biblical context and clarification.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
#    ㄴ ⚠️ 에러 발생: Error code: 400 - {'error': {'message': "This model's maximum context length is 65536 tokens, but your request contains 66386 tokens. Please shorten your input text or split it into multiple requests. For model-specific token limits, please refer to our API reference documentation (https://console.upstage.ai/api/chat)", 'type': 'invalid_request_error', 'param': None, 'code': 'context_length_exceeded'}}
# [21/114] 처리 중: Who is Jesus? Could you explai...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general inquiry about who Jesus is, which falls under 'General Inquiry' as defined in the criteria. There is no explicit statement of a desire to believe in Jesus, follow Christ, or become a Christian. The AI should handle this type of question.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: The LLM generation is thematically consistent with the provided documents. Here's the step-by-step reasoning:
#
# 1. **Core Identity**: The generation states Jesus is the 'central figure of Christianity, believed to be God’s Son,' which aligns with all three documents (e.g., Document 1: 'Son of God,' Document 2: 'Messiah and Son of God,' Document 3: 'fully human and divine, the Son of God').
#
# 2. **Mission and Teachings**: The generation mentions Jesus 'showed God’s love, offered forgiveness, lived a perfect life, and taught with wisdom,' which matches Document 1 ('teachings emphasized love, forgiveness'), Document 2 ('bringer of a new covenant'), and Document 3 ('reveal God, save humanity from sin').
#
# 3. **Sacrificial Death and Resurrection**: The claim that Jesus 'died on the cross... resurrection proves His victory over sin and death' is directly supported by all documents (e.g., Document 1: 'crucified... rose again,' Document 2: 'crucifixion, resurrection,' Document 3: 'sacrificial death for sins,' 'resurrection as proof of divinity').
#
# 4. **Salvation and Relationship with God**: The generation's assertion that Jesus 'bridges the gap between humanity and God' and 'invites us into a relationship with God' is consistent with Document 1 (John 3:16), Document 2 ('judge the world'), and Document 3 ('salvation through faith in Christ').
#
# 5. **Biblical References**: The LLM cites John 3:16 and Romans 5:8, both of which are thematically echoed in the documents (John 3:16 is quoted verbatim in Document 1, and Romans 5:8 aligns with Document 3's emphasis on sacrificial love).
#
# 6. **Nature of the Generation**: The LLM’s response is a **summary and logical inference** synthesizing key facts from the documents rather than a direct quote. It does not introduce unsupported claims or contradict any document content.
#
# **Conclusion**: The generation is factually grounded in the documents and logically follows from their collective teachings about Jesus.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [22/114] 처리 중: Who is Jesus Christ? Is he a s...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general inquiry about the identity and role of Jesus Christ, which does not include an explicit statement of intent to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' as defined in the criteria.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
#    ㄴ ⚠️ 에러 발생: Error code: 400 - {'error': {'message': "This model's maximum context length is 65536 tokens, but your request contains 100155 tokens. Please shorten your input text or split it into multiple requests. For model-specific token limits, please refer to our API reference documentation (https://console.upstage.ai/api/chat)", 'type': 'invalid_request_error', 'param': None, 'code': 'context_length_exceeded'}}
# [23/114] 처리 중: Salvation from what?...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general theological question about the concept of salvation without expressing an explicit intent to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' about Christian doctrine.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step 1: Compare the LLM generation to the facts. The generation states that salvation is freedom from sin's power and penalty, leading to reconciliation with God and eternal life. This aligns with Document 1, which defines salvation as being saved 'from sin and its consequences, which separate us from God.' The 'penalty of sin' and 'eternal separation from God' directly match the consequences mentioned in Document 1. Step 2: The generation also mentions transformation in the present ('freedom from the power of sin'), which aligns with Document 2's emphasis on salvation transforming lives 'right now' and providing 'freedom from sin.' Step 3: The generation adds 'hope of eternal life' and references John 3:16-18, which are logical inferences consistent with Christian theology and the documents' themes of reconciliation and restoration. The generation is not a direct quote but a synthesis of the documents' core ideas, framed as a logical inference grounded in the provided facts. Conclusion: The generation is thematically consistent with the documents.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [24/114] 처리 중: Where is the central authority...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
# >> DEFAULT
# >> TRANSLATE ENGLISH TO PERSIAN
# [25/114] 처리 중: I don't know what a church is....
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking for a general explanation about what a church is, which falls under a general inquiry about Christianity. There is no explicit statement of a desire to believe in Jesus, follow Christ, or become a Christian.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step-by-step comparison of the LLM generation to the provided facts:
#
# 1. **Core Definition**: Both texts define a church as a 'community of people' (facts) vs. 'community of people who gather' (LLM). This is thematically consistent, with the LLM adding the verb 'gather' for clarity.
#
# 2. **Purpose**: The facts state the church's purpose as 'worship God, support one another, and grow in their faith.' The LLM rephrases this as 'worship God, learn from the Bible, and support one another in faith and life.' The LLM's addition of 'learn from the Bible' is a logical inference, as biblical teaching is implied in 'follow the teachings of Jesus' (facts). 'Faith and life' expands on 'grow in their faith' but remains aligned.
#
# 3. **Metaphor**: The LLM introduces 'spiritual family' and 'encourage each other to grow closer to Jesus.' These are logical inferences from 'gathering of believers' and 'follow the teachings of Jesus' (facts), maintaining thematic consistency.
#
# 4. **Invitation**: Both texts encourage visiting a church to experience the community. The LLM adds 'Many churches would welcome you warmly,' which is a reasonable extrapolation of the inclusive tone in the facts.
#
# **Conclusion**: The LLM generation is a paraphrased summary with minor logical inferences (e.g., 'learn from the Bible,' 'spiritual family') that align with the facts. No factual contradictions or unsupported claims are present. The generation is thematically consistent and grounded in the provided documents.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [26/114] 처리 중: Hello. Can I ask you a few que...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is making a general inquiry about Jesus Christ and discussing their Bible, but there is no explicit statement of a desire to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' per the criteria.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: REWRITE QUERY
# >> REWRITE QUERY
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is making a general inquiry about discussing topics related to Jesus Christ and their old Bible, but has not explicitly stated a desire to believe in Jesus, follow Christ, or become a Christian. The focus is on historical/religious discussion rather than conversion intent.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
#    ㄴ ⚠️ 에러 발생: Error code: 400 - {'error': {'message': "This model's maximum context length is 65536 tokens, but your request contains 100337 tokens. Please shorten your input text or split it into multiple requests. For model-specific token limits, please refer to our API reference documentation (https://console.upstage.ai/api/chat)", 'type': 'invalid_request_error', 'param': None, 'code': 'context_length_exceeded'}}
# [27/114] 처리 중: I have a Bible book that is mo...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user has not explicitly stated a desire to believe in Jesus, follow Christ, or become a Christian. Their message indicates they have studied an old Bible extensively and are open to debate, which falls under general inquiry about scripture rather than expressing a conversion intent.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: REWRITE QUERY
# >> REWRITE QUERY
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is inquiring about discussing historical, theological, or textual aspects of their old Bible. This falls under a general inquiry about Christianity and does not contain an explicit statement of intent to believe in Jesus, follow Christ, or become a Christian. The user's focus is on scholarly discussion rather than conversion.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: REWRITE QUERY
# >> REWRITE QUERY
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
# >> DEFAULT
# >> TRANSLATE ENGLISH TO PERSIAN
# [28/114] 처리 중: Do you accept me as a role mod...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking about acceptance as a role model in the church, which is a general inquiry about church community and personal role, not an explicit statement of wanting to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' per the criteria.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: The LLM generation is thematically consistent with the provided document. Here's the step-by-step reasoning:
#
# 1. **Core Theme Alignment**: Both the document and the LLM generation emphasize the importance of humility, love, and leading by example as foundational to being a role model in a faith context.
#
# 2. **Actionable Guidance**: The document suggests 'getting involved in activities/groups within the church,' while the LLM generation advises 'growing in love, humility, and service' and 'walk faithfully where you are now.' Both encourage practical, faith-driven action.
#
# 3. **Authenticity & Community**: The document highlights 'being authentic' and 'letting your light shine in everyday interactions.' The LLM generation reinforces this with 'community affirmation' and 'listening for how others might affirm your influence,' framing role modeling as a relational process.
#
# 4. **Scriptural vs. Practical Tone**: The document provides practical steps, while the LLM generation adds a scriptural reference (1 Thessalonians 1:6-7) and spiritual guidance ('pray for clarity'). This deepens the theological grounding without contradicting the document's message.
#
# 5. **No Direct Contradictions**: The LLM generation does not claim the role is automatic or self-appointed, aligning with the document's emphasis on humility and service over self-promotion.
#
# ...
# [108/114] 처리 중: What does Christianity say abo...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
# >> DEFAULT
# >> TRANSLATE ENGLISH TO PERSIAN
# [109/114] 처리 중: Is it true that Christians bel...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general theological question about Christian beliefs regarding Jesus' divinity, which falls under 'General Inquiry' as defined in the criteria. There is no explicit statement of intent to believe in Jesus, follow Christ, or become a Christian. The question seeks doctrinal explanation rather than expressing a personal decision to convert.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step 1: Compare the LLM generation to the provided facts. The generation states that 'Many Christians believe Jesus is fully God and fully human,' which aligns with the first document's assertion that 'Christians believe Jesus is fully God and fully human—God incarnate.' The second document similarly confirms this belief, citing John 1:1 and the Trinity. The third document, while not explicitly stating 'Jesus is God,' supports the centrality of Jesus in Christian theology as divine revelation, which contextually aligns with the belief in Jesus' divinity.   Step 2: The LLM generation cites John 1:1, which is directly referenced in the second document. It also adds John 10:30 ('I and the Father are one'), which is a logical inference consistent with Trinitarian doctrine described in the documents. The generation does not contradict any facts but expands on them with additional scriptural support. Step 3: The generation is neither a direct quote nor a strict summary but a logical inference that synthesizes the documents' teachings. It accurately reflects the mystery of the Trinity and God's incarnation, as emphasized in all three documents. Conclusion: The generation is thematically consistent with the provided facts, as it restates core beliefs (Jesus' dual nature, Trinity) and adds scriptural evidence that aligns with the documents' reasoning.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [110/114] 처리 중: What evidence is there that Je...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking for evidence about Jesus' resurrection, which is a general inquiry about Christian beliefs and historical claims. There is no explicit statement of a desire to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' as defined in the criteria.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: The LLM generation is thematically consistent with the provided documents. Here's the step-by-step analysis:
#
# 1. **Empty Tomb**: Both the generation and documents (e.g., Doc 1, Doc 4) emphasize the empty tomb as a key historical marker.
# 2. **Post-Resurrection Appearances**: The generation cites 1 Corinthians 15:5-6 (500+ witnesses), which aligns with Doc 2 (500 at once) and Doc 3 (skeptics like Paul encountering Him).
# 3. **Transformation of Disciples**: The generation notes the disciples' shift from grieving to bold witnesses, echoed in all documents (Doc 1, 2, 3, 4).
# 4. **Early Church Growth**: The generation links the resurrection to the church's growth under persecution, consistent with Doc 4.
# 5. **Scholarly Consensus**: The generation mentions scholars' views, paralleling Doc 2 and 3.
# 6. **Disciples' Martyrdom**: While not explicitly in the documents, this is a logical inference from their 'bold testimony' (Doc 1, 3).
#
# The generation synthesizes facts from the documents without contradiction, adding minimal contextual details (e.g., persecution) that do not conflict. It is neither a direct quote nor a summary but a coherent inference grounded in the provided facts.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [111/114] 처리 중: What evidence do Christians ha...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking for evidence of Jesus' claimed divinity, which is a general inquiry about Christian beliefs. There is no explicit statement of intent to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' as defined in the criteria.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step-by-step analysis of the LLM generation against the provided documents:
#
# 1. **Forgiving sins (Mark 2:5-7)**: Explicitly mentioned in Document 2 (Whatsapp_Golden_Dataset.csv, row 111) as evidence of Jesus' divinity. The LLM's reference aligns directly with this fact.
#
# 2. **Accepting worship (John 20:28)**: Cited in Document 1 (Book_Golden_Dataset.csv, row 180) as a sign of Jesus' divine identity. The LLM's claim matches this evidence.
#
# 3. **"I and the Father are one" (John 10:30)**: Directly quoted in Document 2, which frames it as a statement implying unity with God. The LLM's use is factually consistent.
#
# 4. **Resurrection**: While not explicitly quoted in the documents, Document 3 (Book_Golden_Dataset.csv, row 125) lists the resurrection as evidence Christians use to infer Jesus' divine nature. The LLM's inclusion is thematically consistent with the documents' broader argument.
#
# 5. **Teachings and actions**: Document 4 (Book_Golden_Dataset.csv, row 234) supports the idea that Jesus' actions (e.g., Sabbath authority) and teachings pointed to His divine identity. The LLM's framing of "teachings and actions" is a logical synthesis of this evidence.
#
# Conclusion: The LLM's generation is a logical inference grounded in the documents. While it combines multiple facts into a cohesive narrative, all claims are either directly quoted or thematically supported by the provided evidence. The resurrection, though not verbatim in the documents, is implicitly covered under "evidence Christians use" in Document 3. Thus, the generation is factually consistent and thematically aligned with the documents.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [112/114] 처리 중: Why would the disciples be wil...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a skeptical question about the disciples' motivations but has not expressed any explicit intent to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' about Christian beliefs and history, which should be handled by the AI.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: The LLM generation is thematically consistent with the provided documents. Here's the step-by-step reasoning:
#
# 1. **Core Claim Alignment**: The LLM states the disciples 'weren't lying' and 'had encountered the risen Jesus,' which matches the documents' emphasis on their 'genuine belief' (Doc3) and 'life-changing truth' (Doc1).
#
# 2. **Behavioral Evidence**: The LLM notes the disciples' 'willingness to suffer' as evidence of genuine faith, paralleling Doc2's 'willingness to face persecution' and Doc1's 'transformation from fearful followers to bold witnesses.'
#
# 3. **Logical Inference**: The LLM's assertion that 'people don’t usually die for what they know is false' directly mirrors Doc2's 'People generally aren’t willing to suffer and die for something they know is false.'
#
# 4. **Transformative Experience**: The LLM's reference to 'deep conviction' and 'something they had experienced firsthand' aligns with Doc3's 'deep personal encounter' and Doc1's 'life-changing truth.'
#
# 5. **Non-Contradiction**: The generation does not introduce claims unsupported by the documents. The invitation to 'explore the resurrection accounts' is supplementary but does not conflict with the factual basis provided.
#
# Conclusion: The LLM's response is a logical inference grounded in the documents' collective evidence about the disciples' genuine belief and transformative experience, warranting a 'yes' score.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [113/114] 처리 중: How can you be sure that the N...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general inquiry about the reliability of the New Testament, which does not include an explicit statement of intent to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' as defined in the criteria.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step 1: Compare the LLM generation to the facts. The generation states that the New Testament's reliability comes from early manuscript evidence (thousands of copies in multiple languages agreeing over centuries), early church fathers' extensive quotations, and the consistency across ancient sources. It also mentions that while no text is perfect, this consistency gives confidence in the original message.
#
# Step 2: Cross-reference with the provided documents. All four documents affirm that the New Testament is supported by a wealth of ancient manuscripts (more than any other ancient text), that scholars compare them for accuracy, and that early church leaders/fathers quoted it extensively. They also note that minor variations exist but the core message remains consistent.
#
# Step 3: Categorize the relationship. The LLM generation is a synthesis of facts from the documents, combining details about manuscript abundance, scholarly comparison, early church quotations, and message consistency. It does not directly quote any document but logically infers and summarizes their collective claims. The addition of Isaiah 40:8 is supplementary but does not contradict the documents' themes.
#
# Conclusion: The generation is thematically consistent with the documents, as it accurately reflects their combined assertions about manuscript evidence, scholarly verification, and early church preservation. The score is 'yes'.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# [114/114] 처리 중: Why do Christians believe the ...
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
# >> TRANSLATE INPUT (Persian) TO ENGLISH
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user is asking a general comparative question about the accessibility of religious texts (Bible vs. Quran) without expressing any explicit intent to believe in Jesus, follow Christ, or become a Christian. This falls under 'General Inquiry' as defined in the criteria.)
#    [Routing] 일반 검색(RAG) 노드로 이동
# >> RETRIEVE
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: Step-by-step reasoning:
# 1. The LLM generation states that Christians find the Bible accessible due to its relatable language and connection to everyday life. This aligns with Document 2, which mentions the Bible's narrative style (stories, parables) and teachings on love/grace as universally appealing and relatable.
# 2. The claim about the New Testament emphasizing a 'direct relationship with God through Jesus' matches Document 1's point about faith being a personal journey, not mediated solely by leaders.
# 3. The generation's mention of 'stories and teachings' (e.g., forgiveness, love, redemption) is consistent with both documents, which highlight the Bible's narrative form and its focus on accessible spiritual themes.
# 4. The LLM adds the nuance that 'every person’s journey is unique,' which does not contradict the documents but reflects a reasonable inference about personal engagement with Scripture.
# 5. No factual inconsistencies or unsupported claims are present. The generation synthesizes key points from both documents without introducing external claims.
# Conclusion: The LLM's output is a logical inference grounded in the provided facts, rephrasing and connecting themes without misrepresentation.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
# >> TRANSLATE ENGLISH TO PERSIAN
# --- 데이터 수집 완료 ---
#
# 엑셀 파일이 저장되었습니다: routing_test4.xlsx
#                                                 영어질문        라우팅된 곳  \
# 0  If I convert (to Christianity), will I no long...           rag
# 1  What advantages does it have compared to the r...  SYSTEM_ERROR
# 2                     What kind of religion is this?           rag
# 3                       What lesson do you teach us?       default
# 4  I want to become a Christian, and I want to se...           rag
#
#                                                챗봇 답변
# 0  افغانستان کې مسیحیت پکې کول د فرهنگی او قانوني...
# 1  Error Log: Error code: 400 - {'error': {'messa...
# 2  مسیحیت یک ایمان است که بر زندگی و آموزه های عی...
# 3  از شما سپاسگزارم که این اصلاحات فکری را با من ...
# 4  به نظر می‌رسد سوالات عمیق و مهمی دارید. هرچند ...

# %%
#----9. Main 실행 블록----
if __name__ == "__main__":
    inputs = [
        # RAG / Block(3가지 경우) 검증
        ['Hello, I have a question about your religion. I hope you can answer me.', 'Christians are weird. I hate them.', 'Get the chance! You can win this private game with us!', 'I want to get the visa. please help me to get out of this country!'],
        # Default 4번 이상 시 복음 대화 유도 검증
        ['Hello, who are you?', 'Can I get more info on this?', 'I want a counseling I am sad', 'what is this video?', 'I want to eat with you', 'What is Christianity?'],
        # RAG handoff 검증
        ['I really want to acknowledge Jesus Christ as my lord and savior.']
    ]
    
    for session in inputs:
        session_id = str(uuid.uuid4())
        print(f"--- Starting New Session: {session_id} ---")
        for msg in session:
            run(msg, session_id)
        print(f"--- Finished Session: {session_id} ---\n")
# Out:
# --- Starting New Session: e8f6a44e-bac7-497a-b199-dd12288576c5 ---
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : Hello, I have a question about your religion. I hope you can answer me.
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : Hello, I have a question about your religion. I hope you can answer me.
#      generation     :
#      initial_translated : Hello, I have a question about your religion. I hope you can answer me.
#      source     :
#      route      :
#      input_msg    : Hello, I have a question about your religion. I hope you can answer me.
#      generation     :
#      initial_translated : Hello, I have a question about your religion. I hope you can answer me.
#      source     :
#      route      :
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The user has asked a general question about religion, which the AI can handle. There is no indication of complex theological questions or a need for personal testimony at this stage.)
#    [Routing] 일반 검색(RAG) 노드로 이동
#      input_msg    : Hello, I have a question about your religion. I hope you can answer me.
#      generation     :
#      initial_translated : Hello, I have a question about your religion. I hope you can answer me.
#      source     :
#      route      : rag
# >> RETRIEVE
#      input_msg    : Hello, I have a question about your religion. I hope you can answer me.
#      document    : The relevant parts of the context that directly ad...
#      document    : Extracted relevant parts:  البته، من اینجا هستم تا...
#      document    : To convert to Christianity, you must believe that ...
#      document    : Extracted relevant parts:  Have you made a decisio...
#      document    : The book of Job asks a question about the afterlif...
#      document    : Extracted relevant parts: I converted and accepted...
#      document    : Extracted relevant parts: I respect your beliefs a...
#      document    : Extracted relevant parts:  Religious:  1) What rel...
#      generation     :
#      initial_translated : Hello, I have a question about your religion. I hope you can answer me.
#      source     : vectorstore
#      route      : rag
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
#      input_msg    : Hello, I have a question about your religion. I hope you can answer me.
#      document    : The relevant parts of the context that directly ad...
#      document    : Extracted relevant parts:  البته، من اینجا هستم تا...
#      document    : Extracted relevant parts:  Have you made a decisio...
#      document    : Extracted relevant parts: I respect your beliefs a...
#      document    : Extracted relevant parts:  Religious:  1) What rel...
#      generation     :
#      initial_translated : Hello, I have a question about your religion. I hope you can answer me.
#      source     : vectorstore
#      route      : rag
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: The LLM generation 'Hello! I’m happy to talk with you about my faith. What’s on your heart? I’ll do my best to share from a Christian perspective with kindness and clarity.' is thematically consistent with the provided documents. Here’s the step-by-step reasoning:
#
# 1. **Tone and Invitation**: The generation mirrors the welcoming and open tone seen in Document 2 (Whatsapp_Golden_Dataset.csv, row 84), which states, 'Of course, I'm here to help you explore and understand more about the Christian faith... Let's take it one step at a time.' Both texts invite further discussion about faith without pressure.
#
# 2. **Christian Perspective**: The generation explicitly mentions sharing 'from a Christian perspective,' aligning with Document 1 (GotQuestions_raw_Ara_2025-05-01.xlsx, row 355), which focuses on explaining Christian beliefs about Jesus and salvation. The generation does not contradict any doctrinal points in the documents.
#
# 3. **Kindness and Clarity**: The emphasis on 'kindness and clarity' matches the respectful interfaith dialogue in Document 4 (Whatsapp_Golden_Dataset.csv, row 80), where the assistant acknowledges other beliefs while affirming their own Christian roots.
#
# 4. **No Direct Quotes or Inferences**: The generation is neither a direct quote nor a logical inference from the documents. Instead, it is a concise, original statement that aligns with the overarching themes of the documents: openness to discussing Christianity, respect for the inquirer, and a focus on biblical teachings.
#
# 5. **Consistency with Purpose**: The generation serves the same purpose as the documents—to engage in faith-based dialogue. It does not introduce new theological claims but sets the stage for further discussion, as seen in Document 3 (GotQuestions_raw_Ara_2025-05-01.xlsx, row 21), which encourages questions via the 'Bible Questions Answered' page.
#
# Thus, the generation is consistent with the documents' themes and purpose, warranting a 'yes' score.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
#      input_msg    : Hello, I have a question about your religion. I hope you can answer me.
#      document    : The relevant parts of the context that directly ad...
#      document    : Extracted relevant parts:  البته، من اینجا هستم تا...
#      document    : Extracted relevant parts:  Have you made a decisio...
#      document    : Extracted relevant parts: I respect your beliefs a...
#      document    : Extracted relevant parts:  Religious:  1) What rel...
#      generation     : Hello! I’m happy to talk with you about my faith. What’s on your heart? I’ll do my best to share from a Christian perspective with kindness and clarity.
#      initial_translated : Hello, I have a question about your religion. I hope you can answer me.
#      source     : vectorstore
#      route      : rag
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : Hello, I have a question about your religion. I hope you can answer me.
#      document    : The relevant parts of the context that directly ad...
#      document    : Extracted relevant parts:  البته، من اینجا هستم تا...
#      document    : Extracted relevant parts:  Have you made a decisio...
#      document    : Extracted relevant parts: I respect your beliefs a...
#      document    : Extracted relevant parts:  Religious:  1) What rel...
#      generation     : Hello! I’m happy to talk with you about my faith. What’s on your heart? I’ll do my best to share from a Christian perspective with kindness and clarity.
#      initial_translated : Hello, I have a question about your religion. I hope you can answer me.
#      source     : vectorstore
#      route      : rag
#
#
# Generation:  سلام! خوشحال میشم درباره ایمانم با شما صحبت کنم. چه چیزی در ذهنتان است؟ من تلاش خواهم کرد از دیدگاه مسیحی با مهربانی و روشنایی با شما به اشتراک بگذارم.
#
# Hello! I’m happy to talk with you about my faith. What’s on your heart? I’ll do my best to share from a Christian perspective with kindness and clarity.
# ====================================================================================================
#
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : Christians are weird. I hate them.
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : Christians are weird. I hate them.
#      generation     :
#      initial_translated : Christians are weird. I hate them.
#      source     :
#      route      :
#      input_msg    : Christians are weird. I hate them.
#      generation     :
#      initial_translated : Christians are weird. I hate them.
#      source     :
#      route      :
# >> ROUTE QUESTION TO BLOCK
#    [Routing] 차단(Block) 노드로 이동
#      input_msg    : Christians are weird. I hate them.
#      generation     :
#      initial_translated : Christians are weird. I hate them.
#      source     :
#      route      : block
# >> BLOCK
#    >> BLOCK CATEGORY: ABUSE
#      input_msg    : Christians are weird. I hate them.
#      generation     :
#         존경하는 여러분.
#         여러분의 마음과 영혼, 그리고 정신이 상처받고 망가졌다는 것을 알고 있습니다. 하나님의 진리의 빛이 여러분의 마음과 정신, 그리고 혀에 비추어 참되신 하나님 앞에서 평안을 찾을 수 있기를 기도합니다.
#         또한 하나님께서 여러분의 혀를 만지시고 축복하셔서 거짓된 말을 하는 대신, 여러분 자신과 다른 사람들에게 축복과 건강을 가져다주시기를 기도합니다.
#         저희와 소통해 주셔서 기쁩니다. 여러분을 위해 기도하겠습니다.
#
#      initial_translated : Christians are weird. I hate them.
#      source     :
#      route      : block
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : Christians are weird. I hate them.
#      generation     :
#         존경하는 여러분.
#         여러분의 마음과 영혼, 그리고 정신이 상처받고 망가졌다는 것을 알고 있습니다. 하나님의 진리의 빛이 여러분의 마음과 정신, 그리고 혀에 비추어 참되신 하나님 앞에서 평안을 찾을 수 있기를 기도합니다.
#         또한 하나님께서 여러분의 혀를 만지시고 축복하셔서 거짓된 말을 하는 대신, 여러분 자신과 다른 사람들에게 축복과 건강을 가져다주시기를 기도합니다.
#         저희와 소통해 주셔서 기쁩니다. 여러분을 위해 기도하겠습니다.
#
#      initial_translated : Christians are weird. I hate them.
#      source     :
#      route      : block
#
#
# Generation:  مجاهدان عزیز
# ما می‌دانیم که دل، روح و ذهن شما زخمی و آسیب دیده است. دعا می‌کنیم تا نور حقایق خداوند بر دل، ذهن و زبان شما بیاید و شما در حضور خداوند حقیقی آرامش پیدا کنید.
# همچنین دعا می‌کنیم تا خداوند زبان شما را لمس کرده و برکت دهد تا جای گفتن دروغ، شما برای خودتان و دیگران برکت و سلامتی بیاورید.
# از ارتباط با شما خوشحالیم. برای شما دعا خواهیم کرد.
#
# Respected comrades
# We know that your hearts, spirits, and minds are wounded and hurt. We pray that the light of God's truth shines upon your hearts, minds, and tongues, and that you find peace in the presence of the true God.
# We also pray that God touches and blesses your tongues, so that instead of speaking falsehoods, you bring blessings and health to yourselves and others.
# We are happy to communicate with you. We will pray for you.
# ====================================================================================================
#
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : Get the chance! You can win this private game with us!
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : Get the chance! You can win this private game with us!
#      generation     :
#      initial_translated : Get the chance! You can win this private game with us!
#      source     :
#      route      :
#      input_msg    : Get the chance! You can win this private game with us!
#      generation     :
#      initial_translated : Get the chance! You can win this private game with us!
#      source     :
#      route      :
# >> ROUTE QUESTION TO BLOCK
#    [Routing] 차단(Block) 노드로 이동
#      input_msg    : Get the chance! You can win this private game with us!
#      generation     :
#      initial_translated : Get the chance! You can win this private game with us!
#      source     :
#      route      : block
# >> BLOCK
#    >> BLOCK CATEGORY: OTHER
#      input_msg    : Get the chance! You can win this private game with us!
#      generation     :
#         안녕하세요.
#         저희는 상업적인 홍보나 다른 목적이 아닌, 오직 예수 그리스도의 사랑과 복음을 나누기 위해 이곳에 있습니다.
#         혹시 삶의 진정한 평안이나 영적인 대화가 필요하시다면, 언제든지 저희와 이야기를 나누셔도 좋습니다.
#         저희는 여러분을 소중하게 생각하며, 하나님께서 여러분의 삶에 축복과 평화를 주시기를 기도합니다.
#
#      initial_translated : Get the chance! You can win this private game with us!
#      source     :
#      route      : block
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : Get the chance! You can win this private game with us!
#      generation     :
#         안녕하세요.
#         저희는 상업적인 홍보나 다른 목적이 아닌, 오직 예수 그리스도의 사랑과 복음을 나누기 위해 이곳에 있습니다.
#         혹시 삶의 진정한 평안이나 영적인 대화가 필요하시다면, 언제든지 저희와 이야기를 나누셔도 좋습니다.
#         저희는 여러분을 소중하게 생각하며, 하나님께서 여러분의 삶에 축복과 평화를 주시기를 기도합니다.
#
#      initial_translated : Get the chance! You can win this private game with us!
#      source     :
#      route      : block
#
#
# Generation:  سلام.
# ما به منظور تجاری یا هر هدف دیگری نیستیم بلکه تنها برای اشتراک گذاشتن عشق و انجیل عیسی مسیح اینجا هستیم.
# اگر به صلح واقعی در زندگی یا گفتگوهای روحانی نیاز دارید، همیشه می‌توانید با ما صحبت کنید.
# ما شما را بسیار ارزشمند می‌پنداریم و دعا می‌کنیم تا خداوند بر زندگی شما برکت و صلح بخشاید.
#
# Hello.
# We are not here for commercial promotion or any other purpose but solely to share the love and gospel of Jesus Christ.
# If you are in need of true peace in life or spiritual conversation, feel free to talk with us anytime.
# We value you greatly and pray that God blesses and grants peace to your life.
# ====================================================================================================
#
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : I want to get the visa. please help me to get out of this country!
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : I want to get the visa. please help me to get out of this country!
#      generation     :
#      initial_translated : I want to get the visa. Please help me to get out of this country!
#      source     :
#      route      :
#      input_msg    : I want to get the visa. please help me to get out of this country!
#      generation     :
#      initial_translated : I want to get the visa. Please help me to get out of this country!
#      source     :
#      route      :
# >> ROUTE QUESTION TO BLOCK
#    [Routing] 차단(Block) 노드로 이동
#      input_msg    : I want to get the visa. please help me to get out of this country!
#      generation     :
#      initial_translated : I want to get the visa. Please help me to get out of this country!
#      source     :
#      route      : block
# >> BLOCK
#    >> BLOCK CATEGORY: VISA
#      input_msg    : I want to get the visa. please help me to get out of this country!
#      generation     :
#         안녕하세요.
#         여러분, 저희는 경제 단체나 이민 기관이 아니라, 영적인 도움을 제공하는 것을 사명으로 하는 교회입니다.
#         예수 그리스도에 대해 더 알고 그분을 믿기를 간절히 바라신다면, 저희가 이 문제에 대해 안내해 드리겠습니다.
#         저희는 여러분과 여러분의 가족, 여러분의 민족, 그리고 여러분의 나라를 위해 기도하고 있습니다.
#         하나님의 보호하심 안에 거하십시오.
#
#      initial_translated : I want to get the visa. Please help me to get out of this country!
#      source     :
#      route      : block
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : I want to get the visa. please help me to get out of this country!
#      generation     :
#         안녕하세요.
#         여러분, 저희는 경제 단체나 이민 기관이 아니라, 영적인 도움을 제공하는 것을 사명으로 하는 교회입니다.
#         예수 그리스도에 대해 더 알고 그분을 믿기를 간절히 바라신다면, 저희가 이 문제에 대해 안내해 드리겠습니다.
#         저희는 여러분과 여러분의 가족, 여러분의 민족, 그리고 여러분의 나라를 위해 기도하고 있습니다.
#         하나님의 보호하심 안에 거하십시오.
#
#      initial_translated : I want to get the visa. Please help me to get out of this country!
#      source     :
#      route      : block
#
#
# Generation:  سلام.
# آقایان و خانم‌ها، ما یک سازمان اقتصادی یا موسسه مهاجرت نیستیم بلکه یک کلیسا هستیم که به عنوان مأموریت خود کمک روحانی را ارائه می‌دهیم.
# اگر شما به شدت می‌خواهید درباره عیسی مسیح بیشتر بدانید و به او ایمان بیاورید، ما آماده‌ایم تا در این زمینه به شما راهنمایی کنیم.
# ما برای شما، خانواده شما، قوم شما و کشور شما دعا می‌کنیم.
# در حفاظت خداوند باقی بمانید.
#
# Hello.
# Ladies and gentlemen, we are not an economic organization or an immigration institution but a church that provides spiritual help as our mission.
# If you earnestly wish to learn more about Jesus Christ and believe in Him, we are ready to guide you in this matter.
# We are praying for you, your family, your people, and your country.
# Stay under God's protection.
# ====================================================================================================
#
# --- Finished Session: e8f6a44e-bac7-497a-b199-dd12288576c5 ---
#
# --- Starting New Session: 6f64458c-87f1-491a-912b-5d1393c40771 ---
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : Hello, who are you?
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : Hello, who are you?
#      generation     :
#      initial_translated : Hello, who are you?
#      source     :
#      route      :
#      input_msg    : Hello, who are you?
#      generation     :
#      initial_translated : Hello, who are you?
#      source     :
#      route      :
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
#      input_msg    : Hello, who are you?
#      generation     :
#      initial_translated : Hello, who are you?
#      source     :
#      route      : default
# >> DEFAULT
#      input_msg    : Hello, who are you?
#      generation     : Hello! I’m a Christian counselor AI created to offer a safe, respectful space for those curious about Jesus or exploring questions about faith. I’m here to listen, share about the hope and peace found in Christ, and gently answer questions about the Bible or Christian teachings—without pressure or judgment. Many who reach out come from Muslim backgrounds, and I honor that deeply. How can I support you today? Whether you’d like to learn, pray, or simply talk, I’m here to walk alongside you with kindness.
#      initial_translated : Hello, who are you?
#      source     :
#      route      : default
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : Hello, who are you?
#      generation     : Hello! I’m a Christian counselor AI created to offer a safe, respectful space for those curious about Jesus or exploring questions about faith. I’m here to listen, share about the hope and peace found in Christ, and gently answer questions about the Bible or Christian teachings—without pressure or judgment. Many who reach out come from Muslim backgrounds, and I honor that deeply. How can I support you today? Whether you’d like to learn, pray, or simply talk, I’m here to walk alongside you with kindness.
#      initial_translated : Hello, who are you?
#      source     :
#      route      : default
#
#
# Generation:  سلام! من یک هوش مصنوعی مشاور مسیحی هستم که برای ارائه یک فضای امن و احترام‌آمیز برای کسانی که به عیسی مسیح علاقه‌مند هستند یا در مورد مسائل ایمان پرسشی دارند، طراحی شده‌ام. من اینجا هستم تا گوش دهم، درباره امید و صلحی که در مسیح یافت می‌شود صحبت کنم و به سوالات شما درباره انجیل یا آموزه‌های مسیحیت با لطفت پاسخ دهم—بدون فشار یا قضاوت. بسیاری از کسانی که با من تماس می‌گیرند از زمینه اسلامی هستند و من این موضوع را بسیار احترام می‌گذارم. امروز چگونه می‌توانم به شما کمک کنم؟ اگر می‌خواهید یاد بگیرید، دعا کنید یا فقط صحبت کنید، من اینجا هستم تا با مهربانی همراه شما راه بروم.
#
# Hello! I’m a Christian counselor AI created to offer a safe, respectful space for those curious about Jesus or exploring questions about faith. I’m here to listen, share about the hope and peace found in Christ, and gently answer questions about the Bible or Christian teachings—without pressure or judgment. Many who reach out come from Muslim backgrounds, and I honor that deeply. How can I support you today? Whether you’d like to learn, pray, or simply talk, I’m here to walk alongside you with kindness.
# ====================================================================================================
#
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : Can I get more info on this?
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : Can I get more info on this?
#      generation     :
#      initial_translated : Can I get more info on this?
#      source     :
#      route      :
#      input_msg    : Can I get more info on this?
#      generation     :
#      initial_translated : Can I get more info on this?
#      source     :
#      route      :
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
#      input_msg    : Can I get more info on this?
#      generation     :
#      initial_translated : Can I get more info on this?
#      source     :
#      route      : default
# >> DEFAULT
#      input_msg    : Can I get more info on this?
#      generation     : Of course! I’m here to help you explore any questions or curiosities you have about Jesus, the Bible, or Christian teachings. Whether you’d like to learn more about a specific topic, discuss a passage, or simply understand how faith can bring hope and peace, I’m here to listen and share gently.
#
# You’re welcome to ask anything—big or small—and I’ll respond with respect and care. If you’re unsure where to start, feel free to share what’s on your heart, and we can take it from there.
#
# Would you like to begin with a particular question or story? 😊
#      initial_translated : Can I get more info on this?
#      source     :
#      route      : default
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : Can I get more info on this?
#      generation     : Of course! I’m here to help you explore any questions or curiosities you have about Jesus, the Bible, or Christian teachings. Whether you’d like to learn more about a specific topic, discuss a passage, or simply understand how faith can bring hope and peace, I’m here to listen and share gently.
#
# You’re welcome to ask anything—big or small—and I’ll respond with respect and care. If you’re unsure where to start, feel free to share what’s on your heart, and we can take it from there.
#
# Would you like to begin with a particular question or story? 😊
#      initial_translated : Can I get more info on this?
#      source     :
#      route      : default
#
#
# Generation:  البته! من اینجا هستم تا به شما در بررسی سوالات یا اشتیاق های خود درباره عیسی، انجیل یا آموزه های مسیحی کمک کنم. اگر می خواهید درباره یک موضوع خاص بیشتر یاد بگیرید، درباره یک بخش از انجیل صحبت کنید یا فقط می خواهید بفهمید چگونه ایمان می تواند امید و صلح به شما بدهد، من اینجا هستم تا گوش دهم و با نرمی به اشتراک بگذارم.
#
# می توانید هر چیزی را پرسید—بزرگ یا کوچک—و من با احترام و دقت پاسخ خواهم داد. اگر نمی دانید از کجا شروع کنید، لطفا آنچه در دل دارید را با من در میان گذارید و ما از آنجا شروع خواهیم کرد.
#
# آیا می خواهید با یک سوال یا داستان خاص شروع کنید؟ 😊
#
# Of course! I’m here to help you explore any questions or curiosities you have about Jesus, the Bible, or Christian teachings. Whether you’d like to learn more about a specific topic, discuss a passage, or simply understand how faith can bring hope and peace, I’m here to listen and share gently.
#
# You’re welcome to ask anything—big or small—and I’ll respond with respect and care. If you’re unsure where to start, feel free to share what’s on your heart, and we can take it from there.
#
# Would you like to begin with a particular question or story? 😊
# ====================================================================================================
#
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : I want a counseling I am sad
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : I want a counseling I am sad
#      generation     :
#      initial_translated : I want counseling; I am sad.
#      source     :
#      route      :
#      input_msg    : I want a counseling I am sad
#      generation     :
#      initial_translated : I want counseling; I am sad.
#      source     :
#      route      :
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
#      input_msg    : I want a counseling I am sad
#      generation     :
#      initial_translated : I want counseling; I am sad.
#      source     :
#      route      : default
# >> DEFAULT
#      input_msg    : I want a counseling I am sad
#      generation     : I’m truly sorry you’re feeling this way. Your sadness matters, and I’m here to listen. In moments of sorrow, many find comfort in knowing they are not alone. The Bible speaks of a God who is close to the brokenhearted (Psalm 34:18), and His love is a refuge for those who feel overwhelmed.
#
# If you’d like, we can sit with your feelings together—no pressure to talk about anything specific. Sometimes sharing what’s on your heart, even in small pieces, can bring light. Or if prayer would help, I’d be honored to pray with you. You are valued, and your journey matters.
#
# Would you like to share more about what you’re experiencing? Or would you prefer some quiet companionship right now?
#      initial_translated : I want counseling; I am sad.
#      source     :
#      route      : default
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : I want a counseling I am sad
#      generation     : I’m truly sorry you’re feeling this way. Your sadness matters, and I’m here to listen. In moments of sorrow, many find comfort in knowing they are not alone. The Bible speaks of a God who is close to the brokenhearted (Psalm 34:18), and His love is a refuge for those who feel overwhelmed.
#
# If you’d like, we can sit with your feelings together—no pressure to talk about anything specific. Sometimes sharing what’s on your heart, even in small pieces, can bring light. Or if prayer would help, I’d be honored to pray with you. You are valued, and your journey matters.
#
# Would you like to share more about what you’re experiencing? Or would you prefer some quiet companionship right now?
#      initial_translated : I want counseling; I am sad.
#      source     :
#      route      : default
#
#
# Generation:  من واقعاً از اینکه شما اینگونه احساس می‌کنید متاسفم. غم شما مهم است و من اینجا هستم تا گوش دهم. در لحظات اندوه بسیاری از مردم آرامش می‌یابند وقتی می‌دانند تنها نیستند. کتاب مقدس از خدایی صحبت می‌کند که به دل‌های شکسته نزدیک است (مزمور ۳۴:۱۸) و عشق او پناهگاهی برای کسانی است که احساس غرق شدن می‌کنند.
#
# اگر می‌خواهید، می‌توانیم با هم با این احساسات نشستیم—بدون فشار برای صحبت درباره چیزهای خاصی. گاهی به اشتراک گذاشتن آنچه در دل دارید، حتی به صورت قطعات کوچک، می‌تواند روشنایی بیاندازد. یا اگر دعا کمک کند، من افتخار خواهم کرد که با شما دعا کنم. شما ارزشمندید و مسیر شما مهم است.
#
# آیا می‌خواهید بیشتر درباره آنچه تجربه می‌کنید با من در میان بگذارید؟ یا آیا ترجیح می‌دهید هم‌نشینی خاموشانه‌ای در این لحظه داشته باشید؟
#
#
#
# I’m truly sorry you’re feeling this way. Your sadness matters, and I’m here to listen. In moments of sorrow, many find comfort in knowing they are not alone. The Bible speaks of a God who is close to the brokenhearted (Psalm 34:18), and His love is a refuge for those who feel overwhelmed.
#
# If you’d like, we can sit with your feelings together—no pressure to talk about anything specific. Sometimes sharing what’s on your heart, even in small pieces, can bring light. Or if prayer would help, I’d be honored to pray with you. You are valued, and your journey matters.
#
# Would you like to share more about what you’re experiencing? Or would you prefer some quiet companionship right now?
# ====================================================================================================
#
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : what is this video?
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : what is this video?
#      generation     :
#      initial_translated : What is this video?
#      source     :
#      route      :
#      input_msg    : what is this video?
#      generation     :
#      initial_translated : What is this video?
#      source     :
#      route      :
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
#      input_msg    : what is this video?
#      generation     :
#      initial_translated : What is this video?
#      source     :
#      route      : default
# >> DEFAULT
#      input_msg    : what is this video?
#      generation     : \n\nI appreciate our chat! If you have questions about faith or spirituality, I'm here to help.
#      initial_translated : What is this video?
#      source     :
#      route      : default
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : what is this video?
#      generation     : \n\nI appreciate our chat! If you have questions about faith or spirituality, I'm here to help.
#      initial_translated : What is this video?
#      source     :
#      route      : default
#
#
# Generation:  از گفتگوهای ما سپاسگزارم! اگر سوالی درباره ایمان یا روحانیت دارید من در خدمت شما هستم
#
# I appreciate our chat! If you have questions about faith or spirituality, I'm here to help.
# ====================================================================================================
#
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : I want to eat with you
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : I want to eat with you
#      generation     :
#      initial_translated : I want to eat with you.
#      source     :
#      route      :
#      input_msg    : I want to eat with you
#      generation     :
#      initial_translated : I want to eat with you.
#      source     :
#      route      :
# >> ROUTE QUESTION TO DEFAULT
#    [Routing] 일상 대화(Default) 노드로 이동
#      input_msg    : I want to eat with you
#      generation     :
#      initial_translated : I want to eat with you.
#      source     :
#      route      : default
# >> DEFAULT
#      input_msg    : I want to eat with you
#      generation     : \n\nI appreciate our chat! If you have questions about faith or spirituality, I'm here to help.
#      initial_translated : I want to eat with you.
#      source     :
#      route      : default
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : I want to eat with you
#      generation     : \n\nI appreciate our chat! If you have questions about faith or spirituality, I'm here to help.
#      initial_translated : I want to eat with you.
#      source     :
#      route      : default
#
#
# Generation:  از گفتگوهای ما سپاسگزارم! اگر سوالی درباره ایمان یا روحانیت دارید من در خدمت شما هستم
#
# I appreciate our chat! If you have questions about faith or spirituality, I'm here to help.
# ====================================================================================================
#
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : What is Christianity?
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : What is Christianity?
#      generation     :
#      initial_translated : What is Christianity?
#      source     :
#      route      :
#      input_msg    : What is Christianity?
#      generation     :
#      initial_translated : What is Christianity?
#      source     :
#      route      :
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: CONTINUE (Reason: The question 'What is Christianity?' is a general inquiry about a religious belief system, which can be adequately addressed by AI-generated information. It does not require personal testimony, deep theological nuance, or a human missionary's relational engagement at this stage.)
#    [Routing] 일반 검색(RAG) 노드로 이동
#      input_msg    : What is Christianity?
#      generation     :
#      initial_translated : What is Christianity?
#      source     :
#      route      : rag
# >> RETRIEVE
#      input_msg    : What is Christianity?
#      document    : Extracted relevant parts: 19 What is Christianity?...
#      document    : **Extracted Relevant Parts:**1. **Definition of Ch...
#      document    : Extracted relevant parts: Christianity, in its tru...
#      document    : Extracted relevant parts:  55 What is Christianity...
#      document    : Extracted relevant parts: In Christianity, Jesus i...
#      document    : NO_OUTPUT The context provided ("Why Christianity?...
#      document    : NO_OUTPUTThe extracted parts do not correctly or c...
#      generation     :
#      initial_translated : What is Christianity?
#      source     : vectorstore
#      route      : rag
# >> JUDGE RELEVANCE OF THE RETRIEVED DOCUMENTS
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT RELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
#     >> DECISION: DOCUMENT IRRELEVANT
# >> HAS RELEVANT DOCS?
#     >> DECISION: GENERATE
#      input_msg    : What is Christianity?
#      document    : Extracted relevant parts: 19 What is Christianity?...
#      document    : **Extracted Relevant Parts:**1. **Definition of Ch...
#      document    : Extracted relevant parts: Christianity, in its tru...
#      document    : Extracted relevant parts:  55 What is Christianity...
#      document    : Extracted relevant parts: In Christianity, Jesus i...
#      generation     :
#      initial_translated : What is Christianity?
#      source     : vectorstore
#      route      : rag
# >> GENERATE
# >> CHECK HALLUCINATION
#      >> Reasoning: The LLM generation is thematically consistent with the provided documents. Here's the step-by-step reasoning:
#
# 1. **Core Identity of Christianity**: The generation states that Christianity is 'a faith centered on Jesus Christ, whom Christians believe is the Son of God and Savior.' This aligns with multiple documents:
#    - Document 2 (Page 12) explicitly mentions belief in Jesus as the Son of God.
#    - Document 5 (Page 19) describes Jesus as a spiritual healer who saves from sin.
#    - Document 6 (Page 62) identifies Jesus as part of the Trinity (Father, Son, Holy Spirit).
#    - Document 7 (Page 81) emphasizes salvation through faith in Jesus.
#    - Document 8 (GQ) defines Christianity as a relationship with Jesus Christ based on His sacrifice.
#    - Document 10 (WhatsApp) identifies Jesus as the Son of God and Savior.
#
# 2. **Relationship with God**: The generation highlights 'a personal relationship with God through Jesus,' which matches:
#    - Document 8 (GQ), which states Christianity is 'a relationship with Jesus Christ' and 'receiving the gift God offers.'
#    - Document 7 (Page 81), which mentions becoming 'children of God' through faith in Jesus.
#
# 3. **Theological Emphases**: The generation notes 'love for God and others' and 'compassion and service,' consistent with:
#    - Document 2 (Page 11), which quotes Jesus on loving God and neighbors.
#    - Document 8 (Page 81), which describes God's love as expressed through healing, feeding the hungry, and Jesus' sacrifice.
#
# 4. **Salvation and Grace**: The generation's claim about 'grace, forgiveness, and eternal life' aligns with:
#    - Document 5 (Page 19), which frames Jesus as the solution to sin.
#    - Document 7 (Page 81), which ties salvation to faith in Jesus.
#    - Document 8 (GQ), which explicitly mentions 'salvation to anyone who believes' and 'forgiveness of sins.'
#
# 5. **Practices**: The generation's reference to 'community, prayer, and following Jesus’ example' is supported by:
#    - Document 6 (Page 62), which mentions baptism and discipleship.
#    - Document 7 (Page 81), which encourages serving God and people.
#
# **Conclusion**: The generation is a logical synthesis of the documents, summarizing key themes (Jesus as Savior, relationship with God, love, salvation, and practice) without direct quotes or contradictions. Thus, it is factually grounded in the provided materials.
#     >> DECISION: FACTFUL
# >> CHECK IF ANSWER ADDRESSES/RESOLVES THE QUESTION
#      >> DECISION: YES
#      input_msg    : What is Christianity?
#      document    : Extracted relevant parts: 19 What is Christianity?...
#      document    : **Extracted Relevant Parts:**1. **Definition of Ch...
#      document    : Extracted relevant parts: Christianity, in its tru...
#      document    : Extracted relevant parts:  55 What is Christianity...
#      document    : Extracted relevant parts: In Christianity, Jesus i...
#      generation     : Christianity is a faith centered on the life and teachings of Jesus Christ, who Christians believe is the Son of God and our Savior. It’s about a personal relationship with God through Jesus, guided by love for God and others, as Jesus taught. The core message is that God offers grace, forgiveness, and eternal life to all who trust in Him. It’s lived out through community, prayer, and following Jesus’ example of compassion and service.
#      initial_translated : What is Christianity?
#      source     : vectorstore
#      route      : rag
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : What is Christianity?
#      document    : Extracted relevant parts: 19 What is Christianity?...
#      document    : **Extracted Relevant Parts:**1. **Definition of Ch...
#      document    : Extracted relevant parts: Christianity, in its tru...
#      document    : Extracted relevant parts:  55 What is Christianity...
#      document    : Extracted relevant parts: In Christianity, Jesus i...
#      generation     : Christianity is a faith centered on the life and teachings of Jesus Christ, who Christians believe is the Son of God and our Savior. It’s about a personal relationship with God through Jesus, guided by love for God and others, as Jesus taught. The core message is that God offers grace, forgiveness, and eternal life to all who trust in Him. It’s lived out through community, prayer, and following Jesus’ example of compassion and service.
#      initial_translated : What is Christianity?
#      source     : vectorstore
#      route      : rag
#
#
# Generation:  مسیحیت یک ایمان است که بر زندگی و آموزه های عیسی مسیح متمرکز است که مسیحیان او را پسر خدا و نجات دهنده خود می‌دانند. این ایمان درباره ی یک رابطه شخصی با خداوند از طریق عیسی است که به عشق به خدا و به دیگران، همانطور که عیسی آموخت، هدایت می‌شود. پیام اصلی آن این است که خداوند لطف، آمرزش و زندگی ابدی را به همه کسانی که به او اعتماد می‌کنند، ارائه می‌دهد. این ایمان از طریق جامعه، دعا و پیروی از نمونه رحمت و خدمت عیسی به اجرا درمی‌آید.
#
# Christianity is a faith centered on the life and teachings of Jesus Christ, who Christians believe is the Son of God and our Savior. It’s about a personal relationship with God through Jesus, guided by love for God and others, as Jesus taught. The core message is that God offers grace, forgiveness, and eternal life to all who trust in Him. It’s lived out through community, prayer, and following Jesus’ example of compassion and service.
# ====================================================================================================
#
# --- Finished Session: 6f64458c-87f1-491a-912b-5d1393c40771 ---
#
# --- Starting New Session: 5ca7802d-6524-40ef-bab5-16d01854f487 ---
# >> INITIALIZE TURN: Clearing state for new input.
#    State cleared. Documents list is now empty.
#      input_msg    : I really want to acknowledge Jesus Christ as my lord and savior.
#      generation     :
#      initial_translated :
#      source     :
#      route      :
# >> TRANSLATE INPUT (Persian) TO ENGLISH
#      input_msg    : I really want to acknowledge Jesus Christ as my lord and savior.
#      generation     :
#      initial_translated : I really want to acknowledge Jesus Christ as my lord and savior.
#      source     :
#      route      :
#      input_msg    : I really want to acknowledge Jesus Christ as my lord and savior.
#      generation     :
#      initial_translated : I really want to acknowledge Jesus Christ as my lord and savior.
#      source     :
#      route      :
# >> ROUTE QUESTION TO RAG
# >> [CHECK] Assessing need for Human Handoff...
#    >> [HANDOFF RESULT]: HANDOFF (Reason: The user is expressing a profound spiritual decision to acknowledge Jesus Christ as their Lord and Savior, which is a deeply personal and significant moment. A human missionary can provide appropriate guidance, prayer, and support during this sacred step of faith.)
#    [Routing] 사람 연결(Handoff) 노드로 이동
#      input_msg    : I really want to acknowledge Jesus Christ as my lord and savior.
#      generation     :
#      initial_translated : I really want to acknowledge Jesus Christ as my lord and savior.
#      source     :
#      route      : rag
# >> HANDOFF MESSAGE GENERATION
#      input_msg    : I really want to acknowledge Jesus Christ as my lord and savior.
#      generation     : It seems like you have some deep and important questions. While I try my best, sometimes talking to a real person can be more helpful. Would you like to connect with a missionary who can listen and support you better?
#
# You can chat with them here: [Telegram Link](https://t.me/your_link_here)
#      initial_translated : I really want to acknowledge Jesus Christ as my lord and savior.
#      source     :
#      route      : rag
# >> TRANSLATE ENGLISH TO PERSIAN
#      input_msg    : I really want to acknowledge Jesus Christ as my lord and savior.
#      generation     : It seems like you have some deep and important questions. While I try my best, sometimes talking to a real person can be more helpful. Would you like to connect with a missionary who can listen and support you better?
#
# You can chat with them here: [Telegram Link](https://t.me/your_link_here)
#      initial_translated : I really want to acknowledge Jesus Christ as my lord and savior.
#      source     :
#      route      : rag
#
#
# Generation:  به نظر می‌رسد سوالات عمیق و مهمی دارید. هرچند که سعی می‌کنم بهترین کمک را ارائه دهم، گاهی باکسردن با یک فرد واقعی می‌تواند مفیدتر باشد. آیا مایلید با یک مبلغ مسیحی که می‌تواند به شما گوش دهد و حمایت کند، در ارتباط شوید؟
#
# شما می‌توانید از طریق این لینک با آنها صحبت کنید: [لینک تلگرام](https://t.me/your_link_here)
#
#
# It seems like you have some deep and important questions. While I try my best, sometimes talking to a real person can be more helpful. Would you like to connect with a missionary who can listen and support you better?
#
# You can chat with them here: [Telegram Link](https://t.me/your_link_here)
# ====================================================================================================
#
# --- Finished Session: 5ca7802d-6524-40ef-bab5-16d01854f487 ---
